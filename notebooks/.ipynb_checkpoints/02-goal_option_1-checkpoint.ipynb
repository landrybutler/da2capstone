# %% [markdown]
# # Goals Option 1
#
# ## How much are nearby Hospitals and ASCs paid for the same procedure?
#
# Filters for Physician/Other Supplier
# - Entity Type = O
# - Provider Type = Ambulatory Surgical Center
# - CPT = 43249
#
# Filters for Hospital Outpatient
# - APC = 5302
#
# Compare results within a CBSA
#
# # Stretch Goals
#
# ## Extend to other HCPCS/APCs
# - Best place to start is to find an APC that is well-populated in the Hospital file
# - Next find a well-populated HCPCS from the APC in the Physician/Other Supplier File
#
# ## Compare Doctor Utilization for a procedure
# - Filters for Physician/Other Supplier
#   - Entity Type = I
#   - Place of Service = O
# - HCPCS = 99213 (or any office visit – 99211-99215 / 99201-99205)
# - How many different patients does each specialty typically see in a year? How does that vary by CBSA?

# %% [markdown]
# # To Do List
#
# - Create full_name column for providers and outpatients(?)
# - classification1 dataframe setup is broken, can't import it

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# set up dataframes
providers_tsv = '../data/Medicare_Provider_Util_Payment_PUF_CY2017.tsv'
outpatient_excel = '../data/MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx'
classification1_csv = '../data/508-Compliant-Version-of-2020_january_web_addendum_b.12312019.csv'
classification2_excel = '../data/2020_january_web_addendum_b.12312019.xlsx'
cbsa_excel = '../data/ZIP_CBSA_032020.xlsx'

# NOTE: providers_csv is a TAB-DELIMITED file, Use sep='\t'
providers = pd.read_csv(providers_tsv, sep='\t', low_memory=False) 
outpatient = pd.read_excel(outpatient_excel, skiprows=5) 
# classification1 = pd.read_csv(classification1_csv, engine='python') 
# classification2 = pd.read_excel(classification2_excel) 
classifications = pd.read_excel(classification2_excel) 
cbsa = pd.read_excel(cbsa_excel) 

# NOTE: the first line in providers_tsv is copyright info
outpatient.head()
# Out:
#    Provider ID                     Provider Name Provider Street Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider City Provider\nState  Provider\nZip Code  \
# 0        Dothan              AL               36301
# 1        Dothan              AL               36301
# 2        Dothan              AL               36301
# 3        Dothan              AL               36301
# 4        Dothan              AL               36301
#
#   Provider\nHospital Referral Region\n(HRR)   APC  \
# 0                               AL - Dothan  5072
# 1                               AL - Dothan  5073
# 2                               AL - Dothan  5091
# 3                               AL - Dothan  5092
# 4                               AL - Dothan  5112
#
#                                     APC\nDescription  Beneficiaries  \
# 0    Level 2 Excision/ Biopsy/ Incision and Drainage          249.0
# 1    Level 3 Excision/ Biopsy/ Incision and Drainage           52.0
# 2  Level 1 Breast/Lymphatic Surgery and Related P...           26.0
# 3  Level 2 Breast/Lymphatic Surgery and Related P...           23.0
# 4                 Level 2 Musculoskeletal Procedures           17.0
#
#    Comprehensive APC\nServices  Average\nEstimated\nTotal\nSubmitted\nCharges  \
# 0                          259                                    9575.005714
# 1                           53                                   12578.280189
# 2                           27                                   11337.608889
# 3                           23                                   17116.158261
# 4                           17                                    7382.732353
#
#    Average\nMedicare\nAllowed\nAmount  Average\nMedicare\nPayment\nAmount  \
# 0                         1038.454672                          826.277954
# 1                         1792.596792                         1423.246792
# 2                         2113.580000                         1683.990000
# 3                         3737.140000                         2977.550000
# 4                         1029.460000                          820.210000
#
#    Outlier\nComprehensive\nAPC\nServices  Average\nMedicare\nOutlier\nAmount
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    0.0                                 0.0
# 3                                    0.0                                 0.0
# 4                                    0.0                                 0.0

# %%
# Inner join on HCPS code will eliminate any duplicates
# NOTE: Trailing spaces were found in column names, they're included below and will be removed later
# memory usage after join only increased by 0.5 MB

# classifications = pd.merge(left=classification1, right=classification2, 
#                            how='inner', 
#                            on=['HCPCS Code','Short Descriptor','SI','APC ',
#                                'Relative Weight','Payment Rate ','National Unadjusted Copayment ',
#                               'Minimum Unadjusted Copayment '])
# classifications.info()

# %% [markdown]
# # Format Dataframes
# - clean up column names and make lowercase
# - make provider names and cities lowercase as well

# %%
# column names contain newline characters, remove them
# also convert spaces to underscores and make lowercase
outpatient.columns = outpatient.columns.str.replace('\n', '_').str.replace(' ', '_').str.lower()
providers.columns = providers.columns.str.replace(' ', '_').str.lower()
classifications.columns = classifications.columns.str.replace(' ', '_').str.lower()
cbsa.columns = cbsa.columns.str.replace(' ', '_').str.lower()

providers.head()
# Out:
#           npi                       nppes_provider_last_org_name  \
# 0           1  CPT copyright 2016 American Medical Associatio...
# 1  1003000126                                          ENKESHAFI
# 2  1003000126                                          ENKESHAFI
# 3  1003000126                                          ENKESHAFI
# 4  1003000126                                          ENKESHAFI
#
#   nppes_provider_first_name nppes_provider_mi nppes_credentials  \
# 0                       NaN               NaN               NaN
# 1                   ARDALAN               NaN              M.D.
# 2                   ARDALAN               NaN              M.D.
# 3                   ARDALAN               NaN              M.D.
# 4                   ARDALAN               NaN              M.D.
#
#   nppes_provider_gender nppes_entity_code nppes_provider_street1  \
# 0                   NaN               NaN                    NaN
# 1                     M                 I           900 SETON DR
# 2                     M                 I           900 SETON DR
# 3                     M                 I           900 SETON DR
# 4                     M                 I           900 SETON DR
#
#   nppes_provider_street2 nppes_provider_city  ... hcpcs_code  \
# 0                    NaN                 NaN  ...        NaN
# 1                    NaN          CUMBERLAND  ...      99217
# 2                    NaN          CUMBERLAND  ...      99218
# 3                    NaN          CUMBERLAND  ...      99219
# 4                    NaN          CUMBERLAND  ...      99220
#
#                                    hcpcs_description hcpcs_drug_indicator  \
# 0                                                NaN                  NaN
# 1                Hospital observation care discharge                    N
# 2     Hospital observation care typically 30 minutes                    N
# 3     Hospital observation care typically 50 minutes                    N
# 4  Hospital observation care typically 70 minutes...                    N
#
#   line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 0           NaN             NaN               NaN
# 1         100.0            96.0             100.0
# 2          26.0            25.0              26.0
# 3          52.0            51.0              52.0
# 4          59.0            59.0              59.0
#
#   average_medicare_allowed_amt average_submitted_chrg_amt  \
# 0                          NaN                        NaN
# 1                    73.398800                 325.780000
# 2                   100.080000                 449.000000
# 3                   136.380000                 614.000000
# 4                   190.363729                 755.932203
#
#   average_medicare_payment_amt  average_medicare_standard_amt
# 0                          NaN                            NaN
# 1                    56.827200                      57.492400
# 2                    78.460000                      79.306154
# 3                   102.807692                     103.895385
# 4                   141.293559                     142.865763
#
# [5 rows x 26 columns]

# %%
# make provider names and cities lowercase as well
providers['nppes_provider_last_org_name'] = providers['nppes_provider_last_org_name'].str.capitalize()
providers['nppes_provider_first_name'] = providers['nppes_provider_first_name'].str.capitalize()
providers['nppes_provider_city'] = providers['nppes_provider_city'].str.capitalize()


providers.head()
# Out:
#           npi                       nppes_provider_last_org_name  \
# 0           1  Cpt copyright 2016 american medical associatio...
# 1  1003000126                                          Enkeshafi
# 2  1003000126                                          Enkeshafi
# 3  1003000126                                          Enkeshafi
# 4  1003000126                                          Enkeshafi
#
#   nppes_provider_first_name nppes_provider_mi nppes_credentials  \
# 0                       NaN               NaN               NaN
# 1                   Ardalan               NaN              M.D.
# 2                   Ardalan               NaN              M.D.
# 3                   Ardalan               NaN              M.D.
# 4                   Ardalan               NaN              M.D.
#
#   nppes_provider_gender nppes_entity_code nppes_provider_street1  \
# 0                   NaN               NaN                    NaN
# 1                     M                 I           900 SETON DR
# 2                     M                 I           900 SETON DR
# 3                     M                 I           900 SETON DR
# 4                     M                 I           900 SETON DR
#
#   nppes_provider_street2 nppes_provider_city  ... hcpcs_code  \
# 0                    NaN                 NaN  ...        NaN
# 1                    NaN          Cumberland  ...      99217
# 2                    NaN          Cumberland  ...      99218
# 3                    NaN          Cumberland  ...      99219
# 4                    NaN          Cumberland  ...      99220
#
#                                    hcpcs_description hcpcs_drug_indicator  \
# 0                                                NaN                  NaN
# 1                Hospital observation care discharge                    N
# 2     Hospital observation care typically 30 minutes                    N
# 3     Hospital observation care typically 50 minutes                    N
# 4  Hospital observation care typically 70 minutes...                    N
#
#   line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 0           NaN             NaN               NaN
# 1         100.0            96.0             100.0
# 2          26.0            25.0              26.0
# 3          52.0            51.0              52.0
# 4          59.0            59.0              59.0
#
#   average_medicare_allowed_amt average_submitted_chrg_amt  \
# 0                          NaN                        NaN
# 1                    73.398800                 325.780000
# 2                   100.080000                 449.000000
# 3                   136.380000                 614.000000
# 4                   190.363729                 755.932203
#
#   average_medicare_payment_amt  average_medicare_standard_amt
# 0                          NaN                            NaN
# 1                    56.827200                      57.492400
# 2                    78.460000                      79.306154
# 3                   102.807692                     103.895385
# 4                   141.293559                     142.865763
#
# [5 rows x 26 columns]

# %%
outpatient.head()
# Out:
#    provider_id                     provider_name provider_street_address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   provider_city provider_state  provider_zip_code  \
# 0        Dothan             AL              36301
# 1        Dothan             AL              36301
# 2        Dothan             AL              36301
# 3        Dothan             AL              36301
# 4        Dothan             AL              36301
#
#   provider_hospital_referral_region_(hrr)   apc  \
# 0                             AL - Dothan  5072
# 1                             AL - Dothan  5073
# 2                             AL - Dothan  5091
# 3                             AL - Dothan  5092
# 4                             AL - Dothan  5112
#
#                                      apc_description  beneficiaries  \
# 0    Level 2 Excision/ Biopsy/ Incision and Drainage          249.0
# 1    Level 3 Excision/ Biopsy/ Incision and Drainage           52.0
# 2  Level 1 Breast/Lymphatic Surgery and Related P...           26.0
# 3  Level 2 Breast/Lymphatic Surgery and Related P...           23.0
# 4                 Level 2 Musculoskeletal Procedures           17.0
#
#    comprehensive_apc_services  average_estimated_total_submitted_charges  \
# 0                         259                                9575.005714
# 1                          53                               12578.280189
# 2                          27                               11337.608889
# 3                          23                               17116.158261
# 4                          17                                7382.732353
#
#    average_medicare_allowed_amount  average_medicare_payment_amount  \
# 0                      1038.454672                       826.277954
# 1                      1792.596792                      1423.246792
# 2                      2113.580000                      1683.990000
# 3                      3737.140000                      2977.550000
# 4                      1029.460000                       820.210000
#
#    outlier_comprehensive_apc_services  average_medicare_outlier_amount
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 0.0                              0.0
# 3                                 0.0                              0.0
# 4                                 0.0                              0.0

# %% [markdown]
# # Join Zip to CBSA table with both providers AND outpatient
# - Note: when I convert datatype here, it breaks due to Canadian postal codes. Move this section to after non-Tenn. data has been filtered out

# %%
# providers['nppes_provider_zip'] = pd.to_numeric(providers['nppes_provider_zip'])

# providers.info()

# %% [markdown]
# # Create Full_Name Column in Providers
#
# ## This needs to be added before the individual dataframes are set up
# - IF Entity_Type = O THEN Last_Name
# - IF Entity_Type = I THEN First_Name + “ “ + Middle Initial + “ “ + Last_Name + “, “ + Credentials

# %%
# create full_name column for providers
# df['Price'] = [1500 if x =='Music' else 800 for x in df['Event']] 


# if x > 10:
#   print("Above ten,")
#   if x > 20:
#     print("and also above 20!")
#   else:
#     print("but not above 20.")

    
# if providers['nppes_entity_code'] == 'O':
#     providers['full_name'] = providers['nppes_provider_last_org_name']
#     if providers['nppes_entity_code'] == 'I':
#         providers['full_name'] = providers['nppes_provider_first_name'] + ' '
#         + providers['nppes_provider_mi'] + ' ' + providers['nppes_provider_last_org_name']
#     else:
#         providers['full_name'] = NULL
        


# providers['full_name'] = [nppes_provider_last_org_name 
#                            if x == 'O'
# #                            else nppes_provider_first_name + ' ' 
# #                               + nppes_provider_mi + ' ' 
# #                               + nppes_provider_last_org_name
# #                            for x in providers['nppes_entity_code']
#                            else providers['nppes_provider_first_name'] + ' ' 
#                               + providers['nppes_provider_mi'] + ' ' 
#                               + providers['nppes_provider_last_org_name']
#                            for x in providers['nppes_entity_code']
#                           ]
# providers.head()

# %% [markdown]
# # Set up City Dataframes
#
# We're examining 3 cities: Nashville, Los Angeles, New York City. Starting with Nashville, we set up dataframes and take a look at the procedures done there.

# %%
# set up Nashville Outpatient Dataframe
tennessee_outpatient = outpatient[outpatient ['provider_state'] == 'TN'] 
nashville_outpatient = tennessee_outpatient[tennessee_outpatient ['provider_city'] == 'Nashville'] 
nashville_outpatient
# Out:
#        provider_id                                provider_name  \
# 49924       440006               Tristar Skyline Medical Center
# 49925       440006               Tristar Skyline Medical Center
# 49926       440006               Tristar Skyline Medical Center
# 49927       440006               Tristar Skyline Medical Center
# 49928       440006               Tristar Skyline Medical Center
# ...            ...                                          ...
# 51293       440197        Tristar Southern Hills Medical Center
# 51294       440197        Tristar Southern Hills Medical Center
# 51296       440218  Saint Thomas Hospital For Specialty Surgery
# 51297       440218  Saint Thomas Hospital For Specialty Surgery
# 51298       440218  Saint Thomas Hospital For Specialty Surgery
#
#       provider_street_address provider_city provider_state  provider_zip_code  \
# 49924     3441 Dickerson Pike     Nashville             TN              37207
# 49925     3441 Dickerson Pike     Nashville             TN              37207
# 49926     3441 Dickerson Pike     Nashville             TN              37207
# 49927     3441 Dickerson Pike     Nashville             TN              37207
# 49928     3441 Dickerson Pike     Nashville             TN              37207
# ...                       ...           ...            ...                ...
# 51293          391 Wallace Rd     Nashville             TN              37211
# 51294          391 Wallace Rd     Nashville             TN              37211
# 51296      2011 Murphy Avenue     Nashville             TN              37203
# 51297      2011 Murphy Avenue     Nashville             TN              37203
# 51298      2011 Murphy Avenue     Nashville             TN              37203
#
#       provider_hospital_referral_region_(hrr)   apc  \
# 49924                          TN - Nashville  5072
# 49925                          TN - Nashville  5073
# 49926                          TN - Nashville  5091
# 49927                          TN - Nashville  5092
# 49928                          TN - Nashville  5112
# ...                                       ...   ...
# 51293                          TN - Nashville  5431
# 51294                          TN - Nashville  8011
# 51296                          TN - Nashville  5114
# 51297                          TN - Nashville  5115
# 51298                          TN - Nashville  5431
#
#                                          apc_description  beneficiaries  \
# 49924    Level 2 Excision/ Biopsy/ Incision and Drainage           77.0
# 49925    Level 3 Excision/ Biopsy/ Incision and Drainage           26.0
# 49926  Level 1 Breast/Lymphatic Surgery and Related P...           19.0
# 49927  Level 2 Breast/Lymphatic Surgery and Related P...           11.0
# 49928                 Level 2 Musculoskeletal Procedures           18.0
# ...                                                  ...            ...
# 51293                           Level 1 Nerve Procedures           17.0
# 51294                 Comprehensive Observation Services          118.0
# 51296                 Level 4 Musculoskeletal Procedures          325.0
# 51297                 Level 5 Musculoskeletal Procedures           13.0
# 51298                           Level 1 Nerve Procedures           38.0
#
#        comprehensive_apc_services  average_estimated_total_submitted_charges  \
# 49924                          82                               16658.510122
# 49925                          26                               25117.071923
# 49926                          20                               28844.444500
# 49927                          12                               39405.177500
# 49928                          19                               14518.818421
# ...                           ...                                        ...
# 51293                          19                               24275.466316
# 51294                         121                               18325.429752
# 51296                         334                               22372.576766
# 51297                          13                               50129.440769
# 51298                          44                                9702.966364
#
#        average_medicare_allowed_amount  average_medicare_payment_amount  \
# 49924                      1135.492683                       898.364268
# 49925                      2010.120000                      1601.550000
# 49926                      2244.898500                      1769.688500
# 49927                      4134.010000                      3293.760000
# 49928                      1061.058947                       835.680526
# ...                                ...                              ...
# 51293                      1401.114211                      1103.864211
# 51294                      1983.275785                      1559.381405
# 51296                      4804.725539                      3811.837395
# 51297                      6003.778462                      4687.778462
# 51298                      1435.958409                      1138.708409
#
#        outlier_comprehensive_apc_services  average_medicare_outlier_amount
# 49924                                 0.0                              0.0
# 49925                                 0.0                              0.0
# 49926                                 0.0                              0.0
# 49927                                 0.0                              0.0
# 49928                                 NaN                              NaN
# ...                                   ...                              ...
# 51293                                 0.0                              0.0
# 51294                                 0.0                              0.0
# 51296                                 0.0                              0.0
# 51297                                 0.0                              0.0
# 51298                                 0.0                              0.0
#
# [203 rows x 16 columns]

# %%
# set up Nashville Providers Dataframe
tennessee_providers = providers[providers ['nppes_provider_state'] == 'TN'] 
nashville_providers = tennessee_providers[tennessee_providers ['nppes_provider_city'] == 'Nashville'] 
nashville_providers
# Out:
#                 npi nppes_provider_last_org_name nppes_provider_first_name  \
# 2396     1003013947                         Otto                    Robert
# 2397     1003013947                         Otto                    Robert
# 2398     1003013947                         Otto                    Robert
# 2399     1003013947                         Otto                    Robert
# 2400     1003013947                         Otto                    Robert
# ...             ...                          ...                       ...
# 9845871  1992985949                         Beck                    Robert
# 9845872  1992985949                         Beck                    Robert
# 9846017  1992987085                       Horton                   Susanne
# 9846018  1992987085                       Horton                   Susanne
# 9846019  1992987085                       Horton                   Susanne
#
#         nppes_provider_mi nppes_credentials nppes_provider_gender  \
# 2396                    J              M.D.                     M
# 2397                    J              M.D.                     M
# 2398                    J              M.D.                     M
# 2399                    J              M.D.                     M
# 2400                    J              M.D.                     M
# ...                   ...               ...                   ...
# 9845871                 L               M.D                     M
# 9845872                 L               M.D                     M
# 9846017                 M              CRNA                     F
# 9846018                 M              CRNA                     F
# 9846019                 M              CRNA                     F
#
#         nppes_entity_code           nppes_provider_street1  \
# 2396                    I  2400 PATTERSON STREET SUITE 100
# 2397                    I  2400 PATTERSON STREET SUITE 100
# 2398                    I  2400 PATTERSON STREET SUITE 100
# 2399                    I  2400 PATTERSON STREET SUITE 100
# 2400                    I  2400 PATTERSON STREET SUITE 100
# ...                   ...                              ...
# 9845871                 I                2400 PATTERSON ST
# 9845872                 I                2400 PATTERSON ST
# 9846017                 I           1211 MEDICAL CENTER DR
# 9846018                 I           1211 MEDICAL CENTER DR
# 9846019                 I           1211 MEDICAL CENTER DR
#
#         nppes_provider_street2 nppes_provider_city  ... hcpcs_code  \
# 2396                       NaN           Nashville  ...      20610
# 2397                       NaN           Nashville  ...      27447
# 2398                       NaN           Nashville  ...      72170
# 2399                       NaN           Nashville  ...      73502
# 2400                       NaN           Nashville  ...      73562
# ...                        ...                 ...  ...        ...
# 9845871              SUITE 400           Nashville  ...      G0008
# 9845872              SUITE 400           Nashville  ...      G0439
# 9846017                    NaN           Nashville  ...      00320
# 9846018                    NaN           Nashville  ...      00740
# 9846019                    NaN           Nashville  ...      00810
#
#                                          hcpcs_description  \
# 2396     Aspiration and/or injection of large joint or ...
# 2397                                  Repair of knee joint
# 2398                         X-ray of pelvis, 1 or 2 views
# 2399                   X-ray of hip with pelvis, 2-3 views
# 2400                                X-ray of knee, 3 views
# ...                                                    ...
# 9845871          Administration of influenza virus vaccine
# 9845872  Annual wellness visit, includes a personalized...
# 9846017  Anesthesia for procedure on esophagus and neck...
# 9846018  Anesthesia for procedure on gastrointestinal t...
# 9846019  Anesthesia for procedure on lower intestine us...
#
#         hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 2396                       N          61.0            37.0              60.0
# 2397                       N          26.0            23.0              26.0
# 2398                       N          65.0            65.0              65.0
# 2399                       N          65.0            39.0              65.0
# 2400                       N          43.0            36.0              43.0
# ...                      ...           ...             ...               ...
# 9845871                    N          52.0            52.0              52.0
# 9845872                    N          91.0            91.0              91.0
# 9846017                    N          17.0            16.0              17.0
# 9846018                    N          61.0            58.0              60.0
# 9846019                    N          42.0            42.0              42.0
#
#         average_medicare_allowed_amt average_submitted_chrg_amt  \
# 2396                       64.691967                 268.032787
# 2397                     1307.530385                4319.000000
# 2398                       29.410000                  78.000000
# 2399                       38.310000                 114.000000
# 2400                       35.302326                 107.441860
# ...                              ...                        ...
# 9845871                    23.730000                  67.000000
# 9845872                   109.980000                 312.000000
# 9846017                   186.568824                2194.941176
# 9846018                    76.923443                 917.975410
# 9846019                    83.992143                1002.416667
#
#         average_medicare_payment_amt  average_medicare_standard_amt
# 2396                       47.191311                      54.860164
# 2397                     1021.338846                    1142.162692
# 2398                       21.150000                      25.368308
# 2399                       28.781692                      31.684308
# 2400                       25.268372                      28.054884
# ...                              ...                            ...
# 9845871                    23.260000                      25.320000
# 9845872                   107.780000                     115.360000
# 9846017                   146.270588                     153.111765
# 9846018                    60.307377                      63.126557
# 9846019                    68.004524                      71.220000
#
# [39737 rows x 26 columns]

# %%
# Set up New York City and Los Angeles dataframes
ny_outpatient = outpatient[outpatient ['provider_state'] == 'NY'] 
nyc_outpatient = ny_outpatient[ny_outpatient ['provider_city'] == 'New York'] 
nyc_outpatient

ca_outpatient = outpatient[outpatient ['provider_state'] == 'CA'] 
la_outpatient = ca_outpatient[ca_outpatient ['provider_city'] == 'Los Angeles'] 
la_outpatient

ny_providers = providers[providers ['nppes_provider_state'] == 'NY'] 
nyc_providers = ny_providers[ny_providers ['nppes_provider_city'] == 'New York'] 
nyc_providers

ca_providers = providers[providers ['nppes_provider_state'] == 'CA'] 
la_providers = ca_providers[ca_providers ['nppes_provider_city'] == 'Los Angeles'] 
la_providers
# Out:
# Empty DataFrame
# Columns: [npi, nppes_provider_last_org_name, nppes_provider_first_name, nppes_provider_mi, nppes_credentials, nppes_provider_gender, nppes_entity_code, nppes_provider_street1, nppes_provider_street2, nppes_provider_city, nppes_provider_zip, nppes_provider_state, nppes_provider_country, provider_type, medicare_participation_indicator, place_of_service, hcpcs_code, hcpcs_description, hcpcs_drug_indicator, line_srvc_cnt, bene_unique_cnt, bene_day_srvc_cnt, average_medicare_allowed_amt, average_submitted_chrg_amt, average_medicare_payment_amt, average_medicare_standard_amt]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# # Filter dataframes

# %%
## Filter outpatient
# APC = 5302

# individual statements for filters
tennessee_outpatient = tennessee_outpatient.loc[
    tennessee_outpatient['apc'] == 5302
]

nashville_outpatient = nashville_outpatient.loc[
    nashville_outpatient['apc'] == 5302
]

nyc_outpatient = nyc_outpatient.loc[
    nyc_outpatient['apc'] == 5302
]

la_outpatient = la_outpatient.loc[
    la_outpatient['apc'] == 5302
]

# nyc_outpatient.head()

# %%
## Filter providers
# SELECT entity type = 'O'
# Provider Type = Ambulatory Surgical Center
# CPT/HCPCS = 43249
# DEBUGDEBUG: I'm getting zero rows when I add the hcpcs filter <-------------------------------------


# individual statements for filters
tennessee_providers = tennessee_providers.loc[
    (tennessee_providers['nppes_entity_code'] == 'O') &
    (tennessee_providers['provider_type'] == 'Ambulatory Surgical Center')
   & (tennessee_providers['hcpcs_code'] == '43249')
]

nashville_providers = nashville_providers.loc[
    (nashville_providers['nppes_entity_code'] == 'O') &
    (nashville_providers['provider_type'] == 'Ambulatory Surgical Center')
   & (nashville_providers['hcpcs_code'] == '43249')
]

nyc_providers = nyc_providers.loc[
    (nyc_providers['nppes_entity_code'] == 'O') &
    (nyc_providers['provider_type'] == 'Ambulatory Surgical Center')
    & (nyc_providers['hcpcs_code'] == '43249')
]

la_providers = la_providers.loc[
    (la_providers['nppes_entity_code'] == 'O') &
    (la_providers['provider_type'] == 'Ambulatory Surgical Center')
   & (la_providers['hcpcs_code'] == '43249')
]

tennessee_providers.head()
# Out:
#                 npi           nppes_provider_last_org_name  \
# 990426   1104055425            Wartburg surgery center llc
# 1272943  1124498357  Endoscopy center of inland empire llc
# 2185064  1225039761       Endoscopy center of st thomas lp
# 2881267  1295708964          Columbia tn endoscopy asc llc
# 3187896  1326054172    Fort sanders west op surgery center
#
#         nppes_provider_first_name nppes_provider_mi nppes_credentials  \
# 990426                        NaN               NaN               NaN
# 1272943                       NaN               NaN               NaN
# 2185064                       NaN               NaN               NaN
# 2881267                       NaN               NaN               NaN
# 3187896                       NaN               NaN               NaN
#
#         nppes_provider_gender nppes_entity_code      nppes_provider_street1  \
# 990426                    NaN                 O          1236 KNOXVILLE HWY
# 1272943                   NaN                 O             401 COMMERCE ST
# 2185064                   NaN                 O             4230 HARDING RD
# 2881267                   NaN                 O         1510 1/2 HATCHER LN
# 3187896                   NaN                 O  210 FORT SANDERS WEST BLVD
#
#         nppes_provider_street2 nppes_provider_city  ... hcpcs_code  \
# 990426                     NaN            Wartburg  ...      43249
# 1272943              SUITE 600           Nashville  ...      43249
# 2185064              SUITE 400           Nashville  ...      43249
# 2881267                    NaN            Columbia  ...      43249
# 3187896                    NaN           Knoxville  ...      43249
#
#                                         hcpcs_description  \
# 990426   Balloon dilation of esophagus using an endoscope
# 1272943  Balloon dilation of esophagus using an endoscope
# 2185064  Balloon dilation of esophagus using an endoscope
# 2881267  Balloon dilation of esophagus using an endoscope
# 3187896  Balloon dilation of esophagus using an endoscope
#
#         hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 990426                     N          41.0            36.0              41.0
# 1272943                    N          16.0            16.0              16.0
# 2185064                    N          17.0            16.0              17.0
# 2881267                    N          34.0            29.0              34.0
# 3187896                    N          25.0            22.0              25.0
#
#         average_medicare_allowed_amt average_submitted_chrg_amt  \
# 990426                    512.000000                     2491.5
# 1272943                   660.990000                     2200.0
# 2185064                   565.636471                     1500.0
# 2881267                   587.110000                     2427.0
# 3187896                   524.800000                     1151.5
#
#         average_medicare_payment_amt  average_medicare_standard_amt
# 990426                    401.404878                     465.444390
# 1272943                   512.294375                     484.535000
# 2185064                   435.024706                     468.650588
# 2881267                   454.431471                     471.222941
# 3187896                   398.998000                     480.566800
#
# [5 rows x 26 columns]

# %% [markdown]
# # Add CBSA info

# %%
# convert zip code to numeric fields
tennessee_providers['nppes_provider_zip'] = pd.to_numeric(tennessee_providers['nppes_provider_zip'])
tennessee_outpatient['provider_zip_code'] = pd.to_numeric(tennessee_outpatient['provider_zip_code'])

tennessee_providers = pd.merge(left=tennessee_providers, right=cbsa, left_on='nppes_provider_zip', right_on='zip', how='outer')
tennessee_outpatient = pd.merge(left=tennessee_outpatient, right=cbsa, left_on='provider_zip_code', right_on='zip', how='outer')

tennessee_outpatient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47417 entries, 0 to 47416
# Data columns (total 22 columns):
# provider_id                                  79 non-null float64
# provider_name                                79 non-null object
# provider_street_address                      79 non-null object
# provider_city                                79 non-null object
# provider_state                               79 non-null object
# provider_zip_code                            79 non-null float64
# provider_hospital_referral_region_(hrr)      79 non-null object
# apc                                          79 non-null float64
# apc_description                              79 non-null object
# beneficiaries                                77 non-null float64
# comprehensive_apc_services                   79 non-null float64
# average_estimated_total_submitted_charges    79 non-null float64
# average_medicare_allowed_amount              79 non-null float64
# average_medicare_payment_amount              79 non-null float64
# outlier_comprehensive_apc_services           73 non-null float64
# average_medicare_outlier_amount              73 non-null float64
# zip                                          47417 non-null int64
# cbsa                                         47417 non-null int64
# res_ratio                                    47417 non-null float64
# bus_ratio                                    47417 non-null float64
# oth_ratio                                    47417 non-null float64
# tot_ratio                                    47417 non-null float64
# dtypes: float64(14), int64(2), object(6)
# memory usage: 8.3+ MB

# %%
tennessee_providers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47425 entries, 0 to 47424
# Data columns (total 32 columns):
# npi                                 10 non-null float64
# nppes_provider_last_org_name        10 non-null object
# nppes_provider_first_name           0 non-null object
# nppes_provider_mi                   0 non-null object
# nppes_credentials                   0 non-null object
# nppes_provider_gender               0 non-null object
# nppes_entity_code                   10 non-null object
# nppes_provider_street1              10 non-null object
# nppes_provider_street2              2 non-null object
# nppes_provider_city                 10 non-null object
# nppes_provider_zip                  10 non-null float64
# nppes_provider_state                10 non-null object
# nppes_provider_country              10 non-null object
# provider_type                       10 non-null object
# medicare_participation_indicator    10 non-null object
# place_of_service                    10 non-null object
# hcpcs_code                          10 non-null object
# hcpcs_description                   10 non-null object
# hcpcs_drug_indicator                10 non-null object
# line_srvc_cnt                       10 non-null float64
# bene_unique_cnt                     10 non-null float64
# bene_day_srvc_cnt                   10 non-null float64
# average_medicare_allowed_amt        10 non-null float64
# average_submitted_chrg_amt          10 non-null float64
# average_medicare_payment_amt        10 non-null float64
# average_medicare_standard_amt       10 non-null float64
# zip                                 47415 non-null float64
# cbsa                                47415 non-null float64
# res_ratio                           47415 non-null float64
# bus_ratio                           47415 non-null float64
# oth_ratio                           47415 non-null float64
# tot_ratio                           47415 non-null float64
# dtypes: float64(15), object(17)
# memory usage: 11.9+ MB

# %% [markdown]
# # These Dataframes are Loaded and Ready for Use
#
# ## Outpatients
# - tennessee_outpatient
# - nashville_outpatient
# - nyc_outpatient
# - la_outpatient
#
# ## Providers
# - tennessee_providers
# - nashville_providers
# - nyc_providers
# - la_providers
#
# # Next Steps
# If no more processing, time to save these in new files for analysis
# - tennessee_outpatient_clean
# - nashville_outpatient_clean
# - nyc_outpatient_clean
# - la_outpatient_clean
# - nashville_providers_clean
# - nyc_providers_clean
# - la_providers_clean

# %%
# save clean dataframes
tennessee_outpatient.to_csv('../data/tennessee_outpatient_clean.csv')
nashville_outpatient.to_csv('../data/nashville_outpatient_clean.csv')
tennessee_providers.to_csv('../data/tennessee_providers_clean.csv')
nashville_providers.to_csv('../data/nashville_providers_clean.csv')

# nyc_outpatient.to_csv('../data/nyc_outpatient_clean.csv')
# la_outpatient.to_csv('../data/la_outpatient_clean.csv')
# nyc_providers.to_csv('../data/nyc_providers_clean.csv')
# la_providers.to_csv('../data/la_providers_clean.csv')

# %%
nashville_outpatient
# Out:
#        provider_id                          provider_name  \
# 49935       440006         Tristar Skyline Medical Center
# 50269       440039   Vanderbilt University Medical Center
# 50660       440082             Saint Thomas West Hospital
# 50790       440111       Metro Nashville General Hospital
# 50923       440133          Saint Thomas Midtown Hospital
# 51056       440161      Tristar Centennial Medical Center
# 51288       440197  Tristar Southern Hills Medical Center
#
#            provider_street_address provider_city provider_state  \
# 49935          3441 Dickerson Pike     Nashville             TN
# 50269    1211 Medical Center Drive     Nashville             TN
# 50660  4220 Harding Rd, Po Box 380     Nashville             TN
# 50790           1818 Albion Street     Nashville             TN
# 50923               2000 Church St     Nashville             TN
# 51056        2300 Patterson Street     Nashville             TN
# 51288               391 Wallace Rd     Nashville             TN
#
#        provider_zip_code provider_hospital_referral_region_(hrr)   apc  \
# 49935              37207                          TN - Nashville  5302
# 50269              37232                          TN - Nashville  5302
# 50660              37205                          TN - Nashville  5302
# 50790              37208                          TN - Nashville  5302
# 50923              37236                          TN - Nashville  5302
# 51056              37203                          TN - Nashville  5302
# 51288              37211                          TN - Nashville  5302
#
#                    apc_description  beneficiaries  comprehensive_apc_services  \
# 49935  Level 2 Upper GI Procedures           13.0                          15
# 50269  Level 2 Upper GI Procedures          477.0                         623
# 50660  Level 2 Upper GI Procedures          189.0                         207
# 50790  Level 2 Upper GI Procedures           11.0                          12
# 50923  Level 2 Upper GI Procedures           76.0                          98
# 51056  Level 2 Upper GI Procedures          151.0                         170
# 51288  Level 2 Upper GI Procedures           44.0                          49
#
#        average_estimated_total_submitted_charges  \
# 49935                               14899.436667
# 50269                                7120.824045
# 50660                                6350.164010
# 50790                                4488.787500
# 50923                                8420.009184
# 51056                               11861.729353
# 51288                               20273.752041
#
#        average_medicare_allowed_amount  average_medicare_payment_amount  \
# 49935                      1248.620000                       994.840000
# 50269                      1205.620546                       958.820642
# 50660                      1224.590048                       970.810048
# 50790                      1248.620000                       994.840000
# 50923                      1238.468571                       984.688571
# 51056                      1207.656000                       953.876000
# 51288                      1228.336327                       973.597143
#
#        outlier_comprehensive_apc_services  average_medicare_outlier_amount
# 49935                                 0.0                              0.0
# 50269                                 NaN                              NaN
# 50660                                 0.0                              0.0
# 50790                                 0.0                              0.0
# 50923                                 NaN                              NaN
# 51056                                 0.0                              0.0
# 51288                                 0.0                              0.0

# %%
cbsa
# Out:
#          zip   cbsa  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0        501  35620        0.0        1.0        0.0        1.0
# 1        601  38660        1.0        1.0        1.0        1.0
# 2        602  10380        1.0        1.0        1.0        1.0
# 3        603  10380        1.0        1.0        1.0        1.0
# 4        604  10380        1.0        1.0        1.0        1.0
# ...      ...    ...        ...        ...        ...        ...
# 47410  99925  99999        0.0        0.0        1.0        1.0
# 47411  99926  99999        0.0        0.0        1.0        1.0
# 47412  99927  99999        0.0        0.0        1.0        1.0
# 47413  99928  28540        0.0        0.0        1.0        1.0
# 47414  99929  99999        0.0        0.0        1.0        1.0
#
# [47415 rows x 6 columns]
