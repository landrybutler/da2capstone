# %% [markdown]
# # Join CSV and Shapefiles

# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
# import shapefile, 500Cities_Tracts
census_tracts = gpd.read_file('../data/location/500Cities_Tracts/500Cities_Tracts_Clip.shp')
print(census_tracts.crs)
census_tracts.head( )
# Out:
# epsg:3857
#   place2010    tract2010  ST   PlaceName           plctract10  PlcTrPop10  \
# 0   0107000  01073000100  01  Birmingham  0107000-01073000100        3042
# 1   0107000  01073000300  01  Birmingham  0107000-01073000300        2735
# 2   0107000  01073000400  01  Birmingham  0107000-01073000400        3338
# 3   0107000  01073000500  01  Birmingham  0107000-01073000500        2864
# 4   0107000  01073000700  01  Birmingham  0107000-01073000700        2577
#
#                                             geometry
# 0  POLYGON ((-9653001.056 3974630.899, -9652982.0...
# 1  POLYGON ((-9657462.853 3968794.996, -9657470.2...
# 2  POLYGON ((-9657275.613 3972217.160, -9657275.3...
# 3  POLYGON ((-9660666.407 3968887.964, -9660631.7...
# 4  POLYGON ((-9661391.097 3968591.429, -9661398.2...

# %%
# will this make a difference?
census_tracts.crs = "EPSG:3857"
print(census_tracts.crs)
# Out:
# EPSG:3857

# %%
# Filter rows outside of Nashville
census_tracts = census_tracts[census_tracts.PlaceName == 'Nashville']
census_tracts
# Out:
#       place2010    tract2010  ST  PlaceName           plctract10  PlcTrPop10  \
# 23537   4752006  47037010103  47  Nashville  4752006-47037010103        2377
# 23538   4752006  47037010104  47  Nashville  4752006-47037010104        3070
# 23539   4752006  47037010105  47  Nashville  4752006-47037010105        4268
# 23540   4752006  47037010106  47  Nashville  4752006-47037010106        2668
# 23541   4752006  47037010201  47  Nashville  4752006-47037010201        4041
# ...         ...          ...  ..        ...                  ...         ...
# 23691   4752006  47037019500  47  Nashville  4752006-47037019500        5916
# 23692   4752006  47037019600  47  Nashville  4752006-47037019600        3764
# 24585   4752006  47037010301  47  Nashville  4752006-47037010301           0
# 24586   4752006  47037980100  47  Nashville  4752006-47037980100           0
# 24587   4752006  47037980200  47  Nashville  4752006-47037980200           0
#
# ...

# %%
# import all_providers location info
all_providers = pd.read_csv('../data/location/all_providers_geocoded.csv')
print(all_providers.shape)
all_providers.head(20)
# Out:
# (2316, 9)
#     Unnamed: 0             full_name                    address     address2  \
# 0            0     Ronald Brizendine  #6 sixth street suite 205          NaN
# 1            1  Tayebeh Asad sangabi         1 innis brook lane          NaN
# 2            2          Tim Bongartz      1 medical center blvd          NaN
# 3            3      Frances Thomason      1 medical center blvd          NaN
# 4            4         Jasmine Olive      1 medical center blvd          NaN
# 5            5        Cassondra Horn        1 medical park blvd          NaN
# 6            6     Marilyn Goldstein        1 medical park blvd          NaN
# 7            7         Barbara Smith        1 medical park blvd  Suite 458-w
# 8            8             Mary King        1 medical park blvd          NaN
# 9            9       Cynthia Johnson        1 medical park blvd          NaN
# 10          10         Wendy Weidner        1 medical park blvd          NaN
# ...

# %%
# Filter rows outside of Nashville
all_providers = all_providers[all_providers.city == 'Nashville']
all_providers
# Out:
#       Unnamed: 0                      full_name  \
# 43            43                Leonard Webster
# 45            45                  Carol Ziegler
# 46            46                Nitara Carswell
# 47            47              Lloyda Williamson
# 48            48                Vincent Morelli
# ...          ...                            ...
# 2311        2311               Meredith Coleman
# 2312        2312                    John Heaphy
# 2313           0      East Public Health Center
# 2314           1  Woodbine Public Health Center
# 2315           2     Lentz Public Health Center
#
#                                         address  \
# 43                          1005 d.b. todd blvd
# 45                 1005 db todd blvd, suite 300
# 46                    1005 dr d.b. todd jr blvd
# 47                      1005 dr db todd jr blvd
# 48                     1005 dr. d. b. todd blvd
# ...                                         ...
# ...

# %%
# drop rows w/o longitude and latitude
all_providers = all_providers[all_providers['longitude'].notna()]
all_providers.head()
# Out:
#     Unnamed: 0            full_name                           address  \
# 43          43      Leonard Webster               1005 d.b. todd blvd
# 46          46      Nitara Carswell         1005 dr d.b. todd jr blvd
# 47          47    Lloyda Williamson           1005 dr db todd jr blvd
# 54          54       Olabisi Akanbi  1005 dr. d.b. todd jr. boulevard
# 73          73  William Worthington                 101 hillwood blvd
#
#    address2       city state          zip  longitude   latitude
# 43      NaN  Nashville    TN      37208.0  -86.80617  36.168274
# 46      NaN  Nashville    TN  372083501.0  -86.80617  36.168274
# 47      NaN  Nashville    TN  372083501.0  -86.80617  36.168274
# 54      NaN  Nashville    TN  372083599.0  -86.80617  36.168274
# 73      NaN  Nashville    TN  372052811.0  -86.85317  36.122086

# %%
# drop 'unnamed' column
all_providers = all_providers.drop(['Unnamed: 0'], axis=1)
all_providers.head()
# Out:
#               full_name                           address address2       city  \
# 43      Leonard Webster               1005 d.b. todd blvd      NaN  Nashville
# 46      Nitara Carswell         1005 dr d.b. todd jr blvd      NaN  Nashville
# 47    Lloyda Williamson           1005 dr db todd jr blvd      NaN  Nashville
# 54       Olabisi Akanbi  1005 dr. d.b. todd jr. boulevard      NaN  Nashville
# 73  William Worthington                 101 hillwood blvd      NaN  Nashville
#
#    state          zip  longitude   latitude
# 43    TN      37208.0  -86.80617  36.168274
# 46    TN  372083501.0  -86.80617  36.168274
# 47    TN  372083501.0  -86.80617  36.168274
# 54    TN  372083599.0  -86.80617  36.168274
# 73    TN  372052811.0  -86.85317  36.122086

# %%
# add geometry to all_providers
all_providers['geometry'] = all_providers.apply(lambda x: Point((float(x.longitude), 
                                                         float(x.latitude))), axis=1)
all_providers.tail(20)
# Out:
#                           full_name  \
# 2028                   Alvin Powers
# 2040                 Scott Cranford
# 2041                  Steven Walker
# 2084                      Seth Karp
# 2091              George Livingston
# 2097                    James Moore
# 2167                  Kimberly Pace
# 2216                    Daniel Wood
# 2298                  Howard Curlin
# 2299                  Elizabeth Lio
# 2304                Kerri Cavanaugh
# 2307                Galileo Simmons
# 2308               Camellia Koleyni
# 2309               Benjamin Tillman
# 2310                   Rachel Aholt
# 2311               Meredith Coleman
# 2312                    John Heaphy
# 2313      East Public Health Center
# 2314  Woodbine Public Health Center
# 2315     Lentz Public Health Center
#
#                                                address  \
# 2028                                       7465 mrb iv
# 2040                                 7629 highway 70 s
# ...

# %%
# create geodataframe from all_providers
all_providers_geo = gpd.GeoDataFrame(all_providers, 
                           crs = census_tracts.crs, 
                           geometry = all_providers['geometry'])

# %%
all_providers_geo
# Out:
#                           full_name  \
# 43                  Leonard Webster
# 46                  Nitara Carswell
# 47                Lloyda Williamson
# 54                   Olabisi Akanbi
# 73              William Worthington
# ...                             ...
# 2311               Meredith Coleman
# 2312                    John Heaphy
# 2313      East Public Health Center
# 2314  Woodbine Public Health Center
# 2315     Lentz Public Health Center
#
#                                         address  \
# 43                          1005 d.b. todd blvd
# 46                    1005 dr d.b. todd jr blvd
# 47                      1005 dr db todd jr blvd
# 54             1005 dr. d.b. todd jr. boulevard
# 73                            101 hillwood blvd
# ...                                         ...
# 2311                        Vumc anesthesiology
# 2312  Vumc dept of oto med ctr east south tower
# 2313                     1015 East Trinity Lane
# ...

# %%
# take another look at census tracts file, notice geometry is Polygons, compared to Points in all_providers_geo
census_tracts
# Out:
#       place2010    tract2010  ST  PlaceName           plctract10  PlcTrPop10  \
# 23537   4752006  47037010103  47  Nashville  4752006-47037010103        2377
# 23538   4752006  47037010104  47  Nashville  4752006-47037010104        3070
# 23539   4752006  47037010105  47  Nashville  4752006-47037010105        4268
# 23540   4752006  47037010106  47  Nashville  4752006-47037010106        2668
# 23541   4752006  47037010201  47  Nashville  4752006-47037010201        4041
# ...         ...          ...  ..        ...                  ...         ...
# 23691   4752006  47037019500  47  Nashville  4752006-47037019500        5916
# 23692   4752006  47037019600  47  Nashville  4752006-47037019600        3764
# 24585   4752006  47037010301  47  Nashville  4752006-47037010301           0
# 24586   4752006  47037980100  47  Nashville  4752006-47037980100           0
# 24587   4752006  47037980200  47  Nashville  4752006-47037980200           0
#
# ...

# %% [markdown]
# ### Confirm that epsg is 3857  'Spatial Reference System EPSG 3857 (WGS84 Web Mercator)'

# %%
print(census_tracts.crs)
# Out:
# EPSG:3857

# %%
print(all_providers_geo.crs)
# Out:
# EPSG:3857

# %% [markdown]
# ### Check Dtypes

# %%
all_providers_geo.dtypes
# Out:
# full_name      object
# address        object
# address2       object
# city           object
# state          object
# zip           float64
# longitude     float64
# latitude      float64
# geometry     geometry
# dtype: object

# %%
census_tracts.dtypes
# Out:
# place2010       object
# tract2010       object
# ST              object
# PlaceName       object
# plctract10      object
# PlcTrPop10       int64
# geometry      geometry
# dtype: object

# %%
# Spatial Join isn't working for me. I think this is a dead end

###### LEFT JOINS all_providers_geo on LEFT
# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'contains', how='left')
#     This results in a dataframe with only POINT geometry

# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'within', how='left')
#     This results in a dataframe with only POINT geometry

# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'intersects', how='left')
#     This results in a dataframe with only POINT geometry


###### RIGHT JOINS all_providers_geo on LEFT
# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'contains', how='right')
#     This results in a dataframe with only POLYGON geometry

# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'within', how='right')
#     This results in a dataframe with only POLYGON geometry

# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'intersects', how='right')
#     This results in a dataframe with only POLYGON geometry


###### INNER JOINS all_providers_geo on LEFT
# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'contains', how='inner')
#     This results in an empty dataframe

# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'within', how='inner')
#     This results in an empty dataframe

# result = gpd.sjoin(all_providers_geo, census_tracts, op = 'intersects', how='inner')
#     This results in an empty dataframe


###### LEFT JOINS all_providers_geo on RIGHT
# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'contains', how='left')
#     This results in a dataframe with only POLYGON geometry

# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'within', how='left')
#     This results in a dataframe with only POLYGON geometry

# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'intersects', how='left')
#     This results in a dataframe with only POLYGON geometry


###### RIGHT JOINS all_providers_geo on RIGHT
# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'contains', how='right')
#     This results in a dataframe with only POINT geometry

# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'within', how='right')
#     This results in a dataframe with only POINT geometry

# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'intersects', how='right')
#     This results in a dataframe with only POINT geometry


###### INNER JOINS all_providers_geo on RIGHT
# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'contains', how='inner')
#     This results in an empty dataframe

# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'within', how='inner')
#     This results in an empty dataframe

# result = gpd.sjoin(census_tracts, all_providers_geo, op = 'intersects', how='inner')
#     This results in an empty dataframe

# result

# %%
# try merging files
# result = all_providers_geo.merge(census_tracts, on='geometry')
#     This results in an empty dataframe

# result = census_tracts.merge(all_providers_geo, on='geometry')
#     This results in an empty dataframe

# result

# %%
# try concat
result = pd.concat([all_providers_geo, census_tracts])

result
# Out:
#                  full_name                           address address2  \
# 43         Leonard Webster               1005 d.b. todd blvd      NaN
# 46         Nitara Carswell         1005 dr d.b. todd jr blvd      NaN
# 47       Lloyda Williamson           1005 dr db todd jr blvd      NaN
# 54          Olabisi Akanbi  1005 dr. d.b. todd jr. boulevard      NaN
# 73     William Worthington                 101 hillwood blvd      NaN
# ...                    ...                               ...      ...
# 23691                  NaN                               NaN      NaN
# 23692                  NaN                               NaN      NaN
# 24585                  NaN                               NaN      NaN
# 24586                  NaN                               NaN      NaN
# 24587                  NaN                               NaN      NaN
#
#             city state          zip  longitude   latitude  \
# 43     Nashville    TN      37208.0  -86.80617  36.168274
# ...

# %%
# save new dataframes
# result.to_file("../data/location/all_providers_tracts.geojson", driver='GeoJSON')
result.to_file("../data/location/all_providers_tracts.shp")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-6f513a8a3aba> in <module>
#       1 # save new dataframes
#       2 # result.to_file("../data/location/all_providers_tracts.geojson", driver='GeoJSON')
# ----> 3 result.to_file("../data/location/all_providers_tracts.shp")
#
# /opt/anaconda3/envs/geospatial/lib/python3.7/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#     531         from geopandas.io.file import to_file
#     532
# --> 533         to_file(self, filename, driver, schema, index, **kwargs)
#     534
#     535     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# /opt/anaconda3/envs/geospatial/lib/python3.7/site-packages/geopandas/io/file.py in to_file(df, filename, driver, schema, index, **kwargs)
# ...
