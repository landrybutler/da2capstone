# %% [markdown]
# # Import Data and Create Provider Dataframes
#
# - set up the dataframes: outpatient, provider
# - clean up as needed
# - join as needed
# - save cleaned and joined dataframes as 'all_providers'
#
# ## Questions
# - What's the best way to join 'all_providers' with Tenn. City Boundaries … spatial join?
#
# ## Notes
# - This notebook needs some cleaning up. There are several cells that have been commented out as they're no longer used.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Import and Setup Dataframes
# - outpatients seems to list hospitals and medical centers
# - providers lists individual providers
# - need to plot locations of these in order to determine underserved locations

# %%
# Setup filename variables
outpatient_csv = '../data/original/tennessee_outpatient_clean.csv'
providers_tsv = '../data/original/Medicare_Provider_Util_Payment_PUF_CY2017.tsv'

# import files to dataframes
outpatient = pd.read_csv(outpatient_csv, low_memory=False,
                         dtype={"provider_name": object, "provider_street_address": object, "provider_city": object})
providers = pd.read_csv(providers_tsv, sep='\t', low_memory=False)

# %%
providers.tail(50)
# Out:
#                 npi         nppes_provider_last_org_name  \
# 9847394  1992999122                              JOHNSON
# 9847395  1992999122                              JOHNSON
# 9847396  1992999122                              JOHNSON
# 9847397  1992999122                              JOHNSON
# 9847398  1992999122                              JOHNSON
# 9847399  1992999122                              JOHNSON
# 9847400  1992999122                              JOHNSON
# 9847401  1992999437                               RIVERA
# 9847402  1992999437                               RIVERA
# 9847403  1992999437                               RIVERA
# 9847404  1992999452                              HEILMAN
# 9847405  1992999551                                MOLAI
# 9847406  1992999551                                MOLAI
# 9847407  1992999551                                MOLAI
# 9847408  1992999551                                MOLAI
# 9847409  1992999551                                MOLAI
# 9847410  1992999551                                MOLAI
# 9847411  1992999551                                MOLAI
# 9847412  1992999551                                MOLAI
# 9847413  1992999551                                MOLAI
# 9847414  1992999551                                MOLAI
# 9847415  1992999759                              SORIANO
# 9847416  1992999759                              SORIANO
# 9847417  1992999759                              SORIANO
# 9847418  1992999759                              SORIANO
# 9847419  1992999759                              SORIANO
# 9847420  1992999759                              SORIANO
# 9847421  1992999775  SPINE SURGERY CENTER OF EUGENE, LLC
# 9847422  1992999775  SPINE SURGERY CENTER OF EUGENE, LLC
# 9847423  1992999775  SPINE SURGERY CENTER OF EUGENE, LLC
# 9847424  1992999775  SPINE SURGERY CENTER OF EUGENE, LLC
# 9847425  1992999775  SPINE SURGERY CENTER OF EUGENE, LLC
# 9847426  1992999825                            DESCHENES
# 9847427  1992999825                            DESCHENES
# 9847428  1992999825                            DESCHENES
# 9847429  1992999825                            DESCHENES
# 9847430  1992999825                            DESCHENES
# 9847431  1992999825                            DESCHENES
# 9847432  1992999825                            DESCHENES
# 9847433  1992999825                            DESCHENES
# 9847434  1992999825                            DESCHENES
# 9847435  1992999825                            DESCHENES
# 9847436  1992999825                            DESCHENES
# 9847437  1992999825                            DESCHENES
# 9847438  1992999825                            DESCHENES
# 9847439  1992999825                            DESCHENES
# 9847440  1992999874                                JOFFE
# 9847441  1992999874                                JOFFE
# 9847442  1992999874                                JOFFE
# 9847443  1992999874                                JOFFE
#
#         nppes_provider_first_name nppes_provider_mi nppes_credentials  \
# 9847394                   CHARLES                 R              D.O.
# 9847395                   CHARLES                 R              D.O.
# 9847396                   CHARLES                 R              D.O.
# 9847397                   CHARLES                 R              D.O.
# 9847398                   CHARLES                 R              D.O.
# 9847399                   CHARLES                 R              D.O.
# 9847400                   CHARLES                 R              D.O.
# 9847401                      JOSE                 L              M.D.
# 9847402                      JOSE                 L              M.D.
# 9847403                      JOSE                 L              M.D.
# 9847404                      JOHN                 P                DC
# 9847405                    INDIRA               NaN              M.D.
# 9847406                    INDIRA               NaN              M.D.
# 9847407                    INDIRA               NaN              M.D.
# 9847408                    INDIRA               NaN              M.D.
# 9847409                    INDIRA               NaN              M.D.
# 9847410                    INDIRA               NaN              M.D.
# 9847411                    INDIRA               NaN              M.D.
# 9847412                    INDIRA               NaN              M.D.
# 9847413                    INDIRA               NaN              M.D.
# 9847414                    INDIRA               NaN              M.D.
# 9847415                      DINO                 V  RN MSN HSA FNP-C
# 9847416                      DINO                 V  RN MSN HSA FNP-C
# 9847417                      DINO                 V  RN MSN HSA FNP-C
# 9847418                      DINO                 V  RN MSN HSA FNP-C
# 9847419                      DINO                 V  RN MSN HSA FNP-C
# 9847420                      DINO                 V  RN MSN HSA FNP-C
# 9847421                       NaN               NaN               NaN
# 9847422                       NaN               NaN               NaN
# 9847423                       NaN               NaN               NaN
# 9847424                       NaN               NaN               NaN
# 9847425                       NaN               NaN               NaN
# 9847426                  GEOFFREY                 R              M.D.
# 9847427                  GEOFFREY                 R              M.D.
# 9847428                  GEOFFREY                 R              M.D.
# 9847429                  GEOFFREY                 R              M.D.
# 9847430                  GEOFFREY                 R              M.D.
# 9847431                  GEOFFREY                 R              M.D.
# 9847432                  GEOFFREY                 R              M.D.
# 9847433                  GEOFFREY                 R              M.D.
# 9847434                  GEOFFREY                 R              M.D.
# 9847435                  GEOFFREY                 R              M.D.
# 9847436                  GEOFFREY                 R              M.D.
# 9847437                  GEOFFREY                 R              M.D.
# 9847438                  GEOFFREY                 R              M.D.
# 9847439                  GEOFFREY                 R              M.D.
# 9847440                 GABRIELLA               NaN               NaN
# 9847441                 GABRIELLA               NaN               NaN
# 9847442                 GABRIELLA               NaN               NaN
# 9847443                 GABRIELLA               NaN               NaN
#
#         nppes_provider_gender nppes_entity_code      nppes_provider_street1  \
# 9847394                     M                 I         1601 CLINT MOORE RD
# 9847395                     M                 I         1601 CLINT MOORE RD
# 9847396                     M                 I         1601 CLINT MOORE RD
# 9847397                     M                 I         1601 CLINT MOORE RD
# 9847398                     M                 I         1601 CLINT MOORE RD
# 9847399                     M                 I         1601 CLINT MOORE RD
# 9847400                     M                 I         1601 CLINT MOORE RD
# 9847401                     M                 I          1600 S ANDREWS AVE
# 9847402                     M                 I          1600 S ANDREWS AVE
# 9847403                     M                 I          1600 S ANDREWS AVE
# 9847404                     M                 I  2012 CLEVELAND RD W UNIT G
# 9847405                     F                 I             625 E GRAND AVE
# 9847406                     F                 I             625 E GRAND AVE
# 9847407                     F                 I             625 E GRAND AVE
# 9847408                     F                 I             625 E GRAND AVE
# 9847409                     F                 I             625 E GRAND AVE
# 9847410                     F                 I             625 E GRAND AVE
# 9847411                     F                 I             625 E GRAND AVE
# 9847412                     F                 I             625 E GRAND AVE
# 9847413                     F                 I             625 E GRAND AVE
# 9847414                     F                 I             625 E GRAND AVE
# 9847415                     M                 I        171 CLOVER POINT CIR
# 9847416                     M                 I        171 CLOVER POINT CIR
# 9847417                     M                 I        171 CLOVER POINT CIR
# 9847418                     M                 I        171 CLOVER POINT CIR
# 9847419                     M                 I        171 CLOVER POINT CIR
# 9847420                     M                 I        171 CLOVER POINT CIR
# 9847421                   NaN                 O                 1410 OAK ST
# 9847422                   NaN                 O                 1410 OAK ST
# 9847423                   NaN                 O                 1410 OAK ST
# 9847424                   NaN                 O                 1410 OAK ST
# 9847425                   NaN                 O                 1410 OAK ST
# 9847426                     M                 I                1100 9TH AVE
# 9847427                     M                 I                1100 9TH AVE
# 9847428                     M                 I                1100 9TH AVE
# 9847429                     M                 I                1100 9TH AVE
# 9847430                     M                 I                1100 9TH AVE
# 9847431                     M                 I                1100 9TH AVE
# 9847432                     M                 I                1100 9TH AVE
# 9847433                     M                 I                1100 9TH AVE
# 9847434                     M                 I                1100 9TH AVE
# 9847435                     M                 I                1100 9TH AVE
# 9847436                     M                 I                1100 9TH AVE
# 9847437                     M                 I                1100 9TH AVE
# 9847438                     M                 I                1100 9TH AVE
# 9847439                     M                 I                1100 9TH AVE
# 9847440                     F                 I               8260 ATLEE RD
# 9847441                     F                 I               8260 ATLEE RD
# 9847442                     F                 I               8260 ATLEE RD
# 9847443                     F                 I               8260 ATLEE RD
#
#         nppes_provider_street2 nppes_provider_city  ... hcpcs_code  \
# 9847394                    155          BOCA RATON  ...      99238
# 9847395                    155          BOCA RATON  ...      G0179
# 9847396                    155          BOCA RATON  ...      G0180
# 9847397                    155          BOCA RATON  ...      G0328
# 9847398                    155          BOCA RATON  ...      G0402
# 9847399                    155          BOCA RATON  ...      G0403
# 9847400                    155          BOCA RATON  ...      G0439
# 9847401                    NaN     FORT LAUDERDALE  ...      99284
# 9847402                    NaN     FORT LAUDERDALE  ...      99285
# 9847403                    NaN     FORT LAUDERDALE  ...      99291
# 9847404                    NaN               HURON  ...      98941
# 9847405                    NaN           ESCONDIDO  ...      90662
# 9847406                    NaN           ESCONDIDO  ...      90670
# 9847407                    NaN           ESCONDIDO  ...      93000
# 9847408                    NaN           ESCONDIDO  ...      99202
# 9847409                    NaN           ESCONDIDO  ...      99203
# 9847410                    NaN           ESCONDIDO  ...      99213
# 9847411                    NaN           ESCONDIDO  ...      99214
# 9847412                    NaN           ESCONDIDO  ...      G0008
# 9847413                    NaN           ESCONDIDO  ...      G0009
# 9847414                    NaN           ESCONDIDO  ...      G0439
# 9847415                    NaN              GUYTON  ...      81003
# 9847416                    NaN              GUYTON  ...      94640
# 9847417                    NaN              GUYTON  ...      99204
# 9847418                    NaN              GUYTON  ...      99213
# 9847419                    NaN              GUYTON  ...      99214
# 9847420                    NaN              GUYTON  ...      J7620
# 9847421              SUITE 300              EUGENE  ...      62321
# 9847422              SUITE 300              EUGENE  ...      62323
# 9847423              SUITE 300              EUGENE  ...      63047
# 9847424              SUITE 300              EUGENE  ...      64483
# 9847425              SUITE 300              EUGENE  ...      G0260
# 9847426              MS:M4-PFS             SEATTLE  ...      30140
# 9847427              MS:M4-PFS             SEATTLE  ...      30520
# 9847428              MS:M4-PFS             SEATTLE  ...      30901
# 9847429              MS:M4-PFS             SEATTLE  ...      31231
# 9847430              MS:M4-PFS             SEATTLE  ...      31575
# 9847431              MS:M4-PFS             SEATTLE  ...      31575
# 9847432              MS:M4-PFS             SEATTLE  ...      69210
# 9847433              MS:M4-PFS             SEATTLE  ...      69210
# 9847434              MS:M4-PFS             SEATTLE  ...      99203
# 9847435              MS:M4-PFS             SEATTLE  ...      99203
# 9847436              MS:M4-PFS             SEATTLE  ...      99204
# 9847437              MS:M4-PFS             SEATTLE  ...      99204
# 9847438              MS:M4-PFS             SEATTLE  ...      99214
# 9847439              MS:M4-PFS             SEATTLE  ...      99214
# 9847440       MOB 2, SUITE 319      MECHANICSVILLE  ...      99223
# 9847441       MOB 2, SUITE 319      MECHANICSVILLE  ...      99232
# 9847442       MOB 2, SUITE 319      MECHANICSVILLE  ...      99233
# 9847443       MOB 2, SUITE 319      MECHANICSVILLE  ...      99239
#
#                                          hcpcs_description  \
# 9847394  Hospital discharge day management, 30 minutes ...
# 9847395  Physician re-certification for medicare-covere...
# 9847396  Physician certification for medicare-covered h...
# 9847397  Colorectal cancer screening; fecal occult bloo...
# 9847398  Initial preventive physical examination; face-...
# 9847399  Electrocardiogram, routine ecg with 12 leads; ...
# 9847400  Annual wellness visit, includes a personalized...
# 9847401  Emergency department visit, problem of high se...
# 9847402  Emergency department visit, problem with signi...
# 9847403  Critical care delivery critically ill or injur...
# 9847404  Chiropractic manipulative treatment, 3 to 4 sp...
# 9847405    Vaccine for influenza for injection into muscle
# 9847406     Pneumococcal vaccine for injection into muscle
# 9847407  Routine EKG using at least 12 leads including ...
# 9847408  New patient office or other outpatient visit, ...
# 9847409  New patient office or other outpatient visit, ...
# 9847410  Established patient office or other outpatient...
# 9847411  Established patient office or other outpatient...
# 9847412          Administration of influenza virus vaccine
# 9847413             Administration of pneumococcal vaccine
# 9847414  Annual wellness visit, includes a personalized...
# 9847415                          Automated urinalysis test
# 9847416  Respiratory inhaled pressure or nonpressure tr...
# 9847417  New patient office or other outpatient visit, ...
# 9847418  Established patient office or other outpatient...
# 9847419  Established patient office or other outpatient...
# 9847420  Albuterol, up to 2.5 mg and ipratropium bromid...
# 9847421  Injection of substance into spinal canal of up...
# 9847422  Injection of substance into spinal canal of lo...
# 9847423  Partial removal of middle spine bone with rele...
# 9847424  Injections of anesthetic and/or steroid drug i...
# 9847425  Injection procedure for sacroiliac joint; prov...
# 9847426                       Removal of nasal air passage
# 9847427                       Reshaping of nasal cartilage
# 9847428                       Simple control of nose bleed
# 9847429  Diagnostic examination of nasal passages using...
# 9847430  Diagnostic examination of voice box using flex...
# 9847431  Diagnostic examination of voice box using flex...
# 9847432                 Removal of impact ear wax, one ear
# 9847433                 Removal of impact ear wax, one ear
# 9847434  New patient office or other outpatient visit, ...
# 9847435  New patient office or other outpatient visit, ...
# 9847436  New patient office or other outpatient visit, ...
# 9847437  New patient office or other outpatient visit, ...
# 9847438  Established patient office or other outpatient...
# 9847439  Established patient office or other outpatient...
# 9847440  Initial hospital inpatient care, typically 70 ...
# 9847441  Subsequent hospital inpatient care, typically ...
# 9847442  Subsequent hospital inpatient care, typically ...
# 9847443  Hospital discharge day management, more than 3...
#
#         hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 9847394                    N         108.0            89.0             108.0
# 9847395                    N          28.0            17.0              28.0
# 9847396                    N          50.0            45.0              50.0
# 9847397                    N         160.0           160.0             160.0
# 9847398                    N          15.0            15.0              15.0
# 9847399                    N          15.0            15.0              15.0
# 9847400                    N         353.0           353.0             353.0
# 9847401                    N          35.0            35.0              35.0
# 9847402                    N         224.0           216.0             224.0
# 9847403                    N          49.0            49.0              49.0
# 9847404                    N         599.0            73.0             599.0
# 9847405                    Y          42.0            42.0              42.0
# 9847406                    Y          24.0            24.0              24.0
# 9847407                    N          39.0            37.0              39.0
# 9847408                    N          15.0            15.0              15.0
# 9847409                    N          28.0            28.0              28.0
# 9847410                    N         484.0           278.0             484.0
# 9847411                    N         293.0           156.0             293.0
# 9847412                    N          48.0            48.0              48.0
# 9847413                    N          25.0            25.0              25.0
# 9847414                    N          14.0            14.0              14.0
# 9847415                    N          32.0            32.0              32.0
# 9847416                    N          23.0            23.0              23.0
# 9847417                    N          28.0            28.0              28.0
# 9847418                    N          37.0            37.0              37.0
# 9847419                    N         177.0           170.0             177.0
# 9847420                    Y          30.0            27.0              27.0
# 9847421                    N          36.0            33.0              36.0
# 9847422                    N          48.0            40.0              48.0
# 9847423                    N          22.0            22.0              22.0
# 9847424                    N          66.0            42.0              49.0
# 9847425                    N          33.0            20.0              24.0
# 9847426                    N          18.0            18.0              18.0
# 9847427                    N          12.0            12.0              12.0
# 9847428                    N          14.0            14.0              14.0
# 9847429                    N          16.0            13.0              16.0
# 9847430                    N          19.0            17.0              19.0
# 9847431                    N          63.0            56.0              63.0
# 9847432                    N          13.0            13.0              13.0
# 9847433                    N         104.0            92.0             104.0
# 9847434                    N          37.0            37.0              37.0
# 9847435                    N          88.0            88.0              88.0
# 9847436                    N          83.0            83.0              83.0
# 9847437                    N         105.0           105.0             105.0
# 9847438                    N         103.0            84.0             103.0
# 9847439                    N         248.0           175.0             248.0
# 9847440                    N          41.0            41.0              41.0
# 9847441                    N         101.0            57.0             101.0
# 9847442                    N         102.0            55.0             102.0
# 9847443                    N          49.0            49.0              49.0
#
#         average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 9847394                    76.260000                  90.000000
# 9847395                    43.320000                  50.000000
# 9847396                    56.510000                  60.000000
# 9847397                    21.820000                  30.000000
# 9847398                   171.941333                 192.000000
# 9847399                    17.990000                  25.000000
# 9847400                   120.478754                 128.498584
# 9847401                   132.350000                1144.342857
# 9847402                   195.880000                1775.571429
# 9847403                   249.790000                2041.081633
# 9847404                    40.040000                  55.000000
# 9847405                    49.030000                  99.000000
# 9847406                   186.850000                 337.000000
# 9847407                    18.010000                  36.000000
# 9847408                    78.880000                 157.266667
# 9847409                   113.260000                 227.000000
# 9847410                    77.010000                 153.481405
# 9847411                   113.150000                 225.604096
# 9847412                    27.383542                  55.000000
# 9847413                    27.454800                  55.000000
# 9847414                   122.910000                 245.000000
# 9847415                     2.430000                   6.640000
# 9847416                    15.910000                  31.900000
# 9847417                   139.420000                 417.000000
# 9847418                    62.380000                 183.000000
# 9847419                    91.770000                 272.000000
# 9847420                     0.139667                   0.700000
# 9847421                   288.477778                1500.000000
# 9847422                   296.720000                1500.000000
# 9847423                  2803.287273                7500.000000
# 9847424                   325.651667                1500.000000
# 9847425                   256.258182                1481.818182
# 9847426                   722.144444                1987.500000
# 9847427                   369.373333                1866.000000
# 9847428                   104.080000                 284.000000
# 9847429                   237.250000                 656.000000
# 9847430                    73.880000                 347.000000
# 9847431                   127.160000                 347.000000
# 9847432                    34.990000                 147.000000
# 9847433                    52.807212                 147.000000
# 9847434                    80.910000                 143.000000
# 9847435                   117.260000                 290.000000
# 9847436                   137.240000                 284.000000
# 9847437                   176.900000                 431.000000
# 9847438                    83.400000                 198.000000
# 9847439                   116.860000                 345.000000
# 9847440                   203.400000                 496.000000
# 9847441                    72.480000                 176.000000
# 9847442                   104.760000                 254.000000
# 9847443                   107.980000                 262.000000
#
#         average_Medicare_payment_amt  average_Medicare_standard_amt
# 9847394                    59.057870                      56.967500
# 9847395                    32.756786                      31.753929
# 9847396                    43.423800                      41.914600
# 9847397                    21.380000                      21.380000
# 9847398                   168.499333                     165.300000
# 9847399                    10.340000                       9.900000
# 9847400                   118.070255                     115.371048
# 9847401                    99.901714                      89.847429
# 9847402                   148.791562                     133.422098
# 9847403                   190.435714                     172.425714
# 9847404                    28.222688                      29.202988
# 9847405                    48.050000                      48.050000
# 9847406                   183.115000                     183.115000
# 9847407                    11.294615                      10.794103
# 9847408                    32.669333                      31.181333
# 9847409                    64.701071                      62.253571
# 9847410                    49.628202                      47.787025
# 9847411                    82.309898                      79.027133
# 9847412                    26.833542                      25.320000
# 9847413                    26.904800                      25.320000
# 9847414                   120.450000                     115.360000
# 9847415                     2.380000                       3.020000
# 9847416                    12.209130                      12.575217
# 9847417                   105.406071                     106.797500
# 9847418                    47.578378                      49.602703
# 9847419                    68.038870                      69.450282
# 9847420                     0.107667                       0.111333
# 9847421                   219.702222                     202.561667
# 9847422                   226.542500                     208.912500
# 9847423                  2197.769091                    2031.212727
# 9847424                   248.943030                     229.592121
# 9847425                   196.561515                     181.334242
# 9847426                   558.196667                     493.563333
# 9847427                   289.586667                     269.002500
# 9847428                    75.420714                      70.202143
# 9847429                   177.033125                     157.603125
# 9847430                    48.774737                      45.962105
# 9847431                    94.053175                      85.662698
# 9847432                    25.320000                      24.415385
# 9847433                    37.847308                      36.032404
# 9847434                    56.712973                      54.526216
# 9847435                    84.541023                      79.799659
# 9847436                   102.023614                      97.797711
# 9847437                   124.930381                     117.928762
# 9847438                    61.235146                      58.485243
# 9847439                    85.637177                      80.263065
# 9847440                   225.564634                     155.800732
# 9847441                    83.200000                      57.390000
# 9847442                   119.450784                      82.450490
# 9847443                   123.950000                      85.540000
#
# [50 rows x 26 columns]

# %%
# confirm imports
print('\n\nThis is: outpatient')
print(outpatient.info())

print('\n\nThis is: providers')
print(providers.info())
# Out:
# This is: outpatient
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47417 entries, 0 to 47416
# Data columns (total 23 columns):
# Unnamed: 0                                   47417 non-null int64
# provider_id                                  79 non-null float64
# provider_name                                79 non-null object
# provider_street_address                      79 non-null object
# provider_city                                79 non-null object
# provider_state                               79 non-null object
# provider_zip_code                            79 non-null float64
# provider_hospital_referral_region_(hrr)      79 non-null object
# apc                                          79 non-null float64
# apc_description                              79 non-null object
# beneficiaries                                77 non-null float64
# comprehensive_apc_services                   79 non-null float64
# average_estimated_total_submitted_charges    79 non-null float64
# average_medicare_allowed_amount              79 non-null float64
# average_medicare_payment_amount              79 non-null float64
# outlier_comprehensive_apc_services           73 non-null float64
# average_medicare_outlier_amount              73 non-null float64
# zip                                          47417 non-null int64
# cbsa                                         47417 non-null int64
# res_ratio                                    47417 non-null float64
# bus_ratio                                    47417 non-null float64
# oth_ratio                                    47417 non-null float64
# tot_ratio                                    47417 non-null float64
# dtypes: float64(14), int64(3), object(6)
# memory usage: 8.3+ MB
# None
#
#
# This is: providers
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9847444 entries, 0 to 9847443
# Data columns (total 26 columns):
# npi                                 int64
# nppes_provider_last_org_name        object
# nppes_provider_first_name           object
# nppes_provider_mi                   object
# nppes_credentials                   object
# nppes_provider_gender               object
# nppes_entity_code                   object
# nppes_provider_street1              object
# nppes_provider_street2              object
# nppes_provider_city                 object
# nppes_provider_zip                  object
# nppes_provider_state                object
# nppes_provider_country              object
# provider_type                       object
# medicare_participation_indicator    object
# place_of_service                    object
# hcpcs_code                          object
# hcpcs_description                   object
# hcpcs_drug_indicator                object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# bene_day_srvc_cnt                   float64
# average_Medicare_allowed_amt        float64
# average_submitted_chrg_amt          float64
# average_Medicare_payment_amt        float64
# average_Medicare_standard_amt       float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 1.9+ GB
# None

# %% [markdown]
# # Clean Up Column Names and Dtypes

# %%
# make provider names and cities lowercase
providers['nppes_provider_last_org_name'] = providers['nppes_provider_last_org_name'].str.capitalize()
providers['nppes_provider_first_name'] = providers['nppes_provider_first_name'].str.capitalize()
providers['nppes_provider_street1'] = providers['nppes_provider_street1'].str.capitalize()
providers['nppes_provider_street2'] = providers['nppes_provider_street2'].str.capitalize()
providers['nppes_provider_city'] = providers['nppes_provider_city'].str.capitalize()

# %% [markdown]
# Keep these columns from providers:
# - nppes_provider_last_org_name,
# - nppes_provider_first_name,
# - nppes_provider_street1,
# - nppes_provider_street2,
# - nppes_provider_city,
# - nppes_provider_zip,
# - nppes_provider_state,
# - provider_type,
# - hcpcs_code,
# - hcpcs_description

# %%
# create temp files with the fields we need
# providers_tmp = providers[['nppes_provider_last_org_name', 'nppes_provider_first_name', 
#                           'nppes_provider_street1', 'nppes_provider_street2', 'nppes_provider_city',
#                           'nppes_provider_state', 'nppes_provider_zip', 'provider_type', 'hcpcs_code',
#                           'hcpcs_description']]

# UPDATE: I don't think I need provider_type and hcpcs fields so let's not copy them 
providers_tmp = providers[['nppes_provider_last_org_name', 'nppes_provider_first_name', 
                          'nppes_provider_street1', 'nppes_provider_street2', 'nppes_provider_city',
                          'nppes_provider_state', 'nppes_provider_zip']]

providers_tmp = providers_tmp.drop([0])
providers_tmp.head()
# Out:
#   nppes_provider_last_org_name nppes_provider_first_name  \
# 1                    Enkeshafi                   Ardalan
# 2                    Enkeshafi                   Ardalan
# 3                    Enkeshafi                   Ardalan
# 4                    Enkeshafi                   Ardalan
# 5                    Enkeshafi                   Ardalan
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 1           900 seton dr                    NaN          Cumberland
# 2           900 seton dr                    NaN          Cumberland
# 3           900 seton dr                    NaN          Cumberland
# 4           900 seton dr                    NaN          Cumberland
# 5           900 seton dr                    NaN          Cumberland
#
#   nppes_provider_state nppes_provider_zip
# 1                   MD          215021854
# 2                   MD          215021854
# 3                   MD          215021854
# 4                   MD          215021854
# 5                   MD          215021854

# %%
# combine first and last names into 'full_name' field
# df['Name'] = df['First'].str.cat(df['Last'],sep=" ")

providers_tmp['full_name'] = providers_tmp['nppes_provider_first_name'].str.cat(providers_tmp['nppes_provider_last_org_name'],sep=' ')
                                         
                                         

providers_tmp.tail()
# Out:
#         nppes_provider_last_org_name nppes_provider_first_name  \
# 9847439                    Deschenes                  Geoffrey
# 9847440                        Joffe                 Gabriella
# 9847441                        Joffe                 Gabriella
# 9847442                        Joffe                 Gabriella
# 9847443                        Joffe                 Gabriella
#
#         nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 9847439           1100 9th ave              Ms:m4-pfs             Seattle
# 9847440          8260 atlee rd       Mob 2, suite 319      Mechanicsville
# 9847441          8260 atlee rd       Mob 2, suite 319      Mechanicsville
# 9847442          8260 atlee rd       Mob 2, suite 319      Mechanicsville
# 9847443          8260 atlee rd       Mob 2, suite 319      Mechanicsville
#
#         nppes_provider_state nppes_provider_zip           full_name
# 9847439                   WA          981012756  Geoffrey Deschenes
# 9847440                   VA          231161844     Gabriella Joffe
# 9847441                   VA          231161844     Gabriella Joffe
# 9847442                   VA          231161844     Gabriella Joffe
# 9847443                   VA          231161844     Gabriella Joffe

# %%
# exclude non-Tennessee records
tennessee_providers = providers_tmp.loc[providers_tmp ['nppes_provider_state'] == 'TN'] 

# convert zip code to int
tennessee_providers.nppes_provider_zip = tennessee_providers.nppes_provider_zip.astype('int64') 

# confirm the fix
print(tennessee_providers.info())
tennessee_providers.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269452 entries, 416 to 9847080
# Data columns (total 8 columns):
# nppes_provider_last_org_name    269448 non-null object
# nppes_provider_first_name       259479 non-null object
# nppes_provider_street1          269452 non-null object
# nppes_provider_street2          115651 non-null object
# nppes_provider_city             269452 non-null object
# nppes_provider_state            269452 non-null object
# nppes_provider_zip              269452 non-null int64
# full_name                       259475 non-null object
# dtypes: int64(1), object(7)
# memory usage: 18.5+ MB
# None
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#         nppes_provider_last_org_name nppes_provider_first_name  \
# 9847076                        Giles                    Wesley
# 9847077                        Giles                    Wesley
# 9847078                        Giles                    Wesley
# 9847079                        Giles                    Wesley
# 9847080                        Giles                    Wesley
#
#         nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 9847076   979 e 3rd st ste 300                    NaN         Chattanooga
# 9847077   979 e 3rd st ste 300                    NaN         Chattanooga
# 9847078   979 e 3rd st ste 300                    NaN         Chattanooga
# 9847079   979 e 3rd st ste 300                    NaN         Chattanooga
# 9847080   979 e 3rd st ste 300                    NaN         Chattanooga
#
#         nppes_provider_state  nppes_provider_zip     full_name
# 9847076                   TN           374032187  Wesley Giles
# 9847077                   TN           374032187  Wesley Giles
# 9847078                   TN           374032187  Wesley Giles
# 9847079                   TN           374032187  Wesley Giles
# 9847080                   TN           374032187  Wesley Giles

# %% [markdown]
# Keep these columns from outpatient:
# - provider_name,
# - provider_street_address,
# - provider_city,
# - provider_state,
# - provider_zip_code,
# - apc,
# - apc_description,
# - beneficiaries

# %%
# create temp files with the fields we need
# outpatient_tmp = outpatient[['provider_name', 'provider_street_address', 'provider_city', 'provider_state',
#                              'provider_zip_code', 'apc', 'apc_description'
# ]]

# UPDATE: don't think I need apc fields
outpatient_tmp = outpatient[['provider_name', 'provider_street_address', 'provider_city', 'provider_state',
                             'provider_zip_code']]

print(outpatient_tmp.info())
outpatient_tmp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47417 entries, 0 to 47416
# Data columns (total 5 columns):
# provider_name              79 non-null object
# provider_street_address    79 non-null object
# provider_city              79 non-null object
# provider_state             79 non-null object
# provider_zip_code          79 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 1.8+ MB
# None
#                              provider_name provider_street_address  \
# 0  Jackson-Madison County General Hospital       620 Skyline Drive
# 1  Jackson-Madison County General Hospital       620 Skyline Drive
# 2           Sumner Regional Medical Center     555 Hartsville Pike
# 3           Tristar Skyline Medical Center     3441 Dickerson Pike
# 4                Cumberland Medical Center           421 S Main St
#
#   provider_city provider_state  provider_zip_code
# 0       Jackson             TN            38301.0
# 1       Jackson             TN            38301.0
# 2      Gallatin             TN            37066.0
# 3     Nashville             TN            37207.0
# 4    Crossville             TN            38555.0

# %% [markdown]
# # Clean up Column Names

# %%
# rename columns
# tennessee_providers.columns = ['last_name', 'first_name', 'address', 'address2', 'city', 'state', 'zip',
#                               'provider_type', 'hcpcs_code', 'hcpcs_description', 'full_name'] 

tennessee_providers.columns = ['last_name', 'first_name', 'address', 'address2', 'city', 'state', 'zip', 'full_name'] 

# outpatient_tmp.columns = ['full_name', 'address', 'city', 'state', 'zip', 'apc', 'apc_description']
outpatient_tmp.columns = ['full_name', 'address', 'city', 'state', 'zip']

# %%
# confirm renames
print('This is tennessee_providers')
tennessee_providers.info()
# Out:
# This is tennessee_providers
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269452 entries, 416 to 9847080
# Data columns (total 8 columns):
# last_name     269448 non-null object
# first_name    259479 non-null object
# address       269452 non-null object
# address2      115651 non-null object
# city          269452 non-null object
# state         269452 non-null object
# zip           269452 non-null int64
# full_name     259475 non-null object
# dtypes: int64(1), object(7)
# memory usage: 18.5+ MB

# %%
print('\n\nThis is outpatient_tmp')
outpatient_tmp.info()
# Out:
# This is outpatient_tmp
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47417 entries, 0 to 47416
# Data columns (total 5 columns):
# full_name    79 non-null object
# address      79 non-null object
# city         79 non-null object
# state        79 non-null object
# zip          79 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Look for NaNs and duplicates

# %%
tennessee_providers.head(10)
# Out:
#          last_name first_name               address   address2       city  \
# 416   Walgreen co.        NaN  5104 bobby hicks hwy        NaN       Gray
# 417   Walgreen co.        NaN  5104 bobby hicks hwy        NaN       Gray
# 418   Walgreen co.        NaN  5104 bobby hicks hwy        NaN       Gray
# 419   Walgreen co.        NaN  5104 bobby hicks hwy        NaN       Gray
# 420   Walgreen co.        NaN  5104 bobby hicks hwy        NaN       Gray
# 1747       Cudzilo      Corey   2240 sutherland ave  Suite 103  Knoxville
# 1748       Cudzilo      Corey   2240 sutherland ave  Suite 103  Knoxville
# 1749       Cudzilo      Corey   2240 sutherland ave  Suite 103  Knoxville
# 1750       Cudzilo      Corey   2240 sutherland ave  Suite 103  Knoxville
# 1751       Cudzilo      Corey   2240 sutherland ave  Suite 103  Knoxville
#
#      state        zip      full_name
# 416     TN  376156217            NaN
# 417     TN  376156217            NaN
# 418     TN  376156217            NaN
# 419     TN  376156217            NaN
# 420     TN  376156217            NaN
# 1747    TN  379192333  Corey Cudzilo
# 1748    TN  379192333  Corey Cudzilo
# 1749    TN  379192333  Corey Cudzilo
# 1750    TN  379192333  Corey Cudzilo
# 1751    TN  379192333  Corey Cudzilo

# %%
tennessee_providers.tail(10)
# Out:
#         last_name first_name               address address2         city  \
# 9847071     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847072     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847073     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847074     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847075     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847076     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847077     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847078     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847079     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
# 9847080     Giles     Wesley  979 e 3rd st ste 300      NaN  Chattanooga
#
#         state        zip     full_name
# 9847071    TN  374032187  Wesley Giles
# 9847072    TN  374032187  Wesley Giles
# 9847073    TN  374032187  Wesley Giles
# 9847074    TN  374032187  Wesley Giles
# 9847075    TN  374032187  Wesley Giles
# 9847076    TN  374032187  Wesley Giles
# 9847077    TN  374032187  Wesley Giles
# 9847078    TN  374032187  Wesley Giles
# 9847079    TN  374032187  Wesley Giles
# 9847080    TN  374032187  Wesley Giles

# %%
# drop duplicates
tennessee_providers = tennessee_providers.drop_duplicates(keep=False)
tennessee_providers
# Out:
#                   last_name first_name                    address   address2  \
# 6354                  Stone      Ralph          1700 carmack blvd        NaN
# 15768    State of tennessee        NaN    214 west longview drive        NaN
# 17080                 Davis    Patrick  1222 trotwood ave ste 603        NaN
# 26250                  Horn  Cassondra        1 medical park blvd        NaN
# 27899                 Hiatt      Emily             3310 w end ave  Suite 590
# ...                     ...        ...                        ...        ...
# 9834934                Shah    Jasmine               975 e 3rd st        NaN
# 9834942               Basty      Marie            713 cheatham st        NaN
# 9839309                Bell     Amanda          317 n hickory ave        NaN
# 9840208                Gill    Farrukh          5301 virginia way  Suite 300
# 9841223               Perry     Amanda      1124 new highway 52 e        NaN
#
#                  city state        zip       full_name
# 6354         Columbia    TN      38401     Ralph Stone
# 15768        Portland    TN      37148             NaN
# 17080        Columbia    TN      38401   Patrick Davis
# 26250         Bristol    TN  376207430  Cassondra Horn
# 27899       Nashville    TN  372031028     Emily Hiatt
# ...               ...   ...        ...             ...
# 9834934   Chattanooga    TN  374032147    Jasmine Shah
# 9834942   Springfield    TN  371722828     Marie Basty
# 9839309    Cookeville    TN  385012428     Amanda Bell
# 9840208     Brentwood    TN  370277541    Farrukh Gill
# 9841223  Westmoreland    TN  371865060    Amanda Perry
#
# [1997 rows x 8 columns]

# %%
outpatient_tmp.head(80)
# Out:
#                                   full_name                    address  \
# 0   Jackson-Madison County General Hospital          620 Skyline Drive
# 1   Jackson-Madison County General Hospital          620 Skyline Drive
# 2            Sumner Regional Medical Center        555 Hartsville Pike
# 3            Tristar Skyline Medical Center        3441 Dickerson Pike
# 4                 Cumberland Medical Center              421 S Main St
# ..                                      ...                        ...
# 75               Tennova Healthcare-Lebanon       1411 Baddour Parkway
# 76    Tristar Hendersonville Medical Center  355 New Shackle Island Rd
# 77    Tristar Southern Hills Medical Center             391 Wallace Rd
# 78        Tristar Stonecrest Medical Center   200 Stonecrest Boulevard
# 79                                      NaN                        NaN
#
#               city state      zip
# 0          Jackson    TN  38301.0
# 1          Jackson    TN  38301.0
# 2         Gallatin    TN  37066.0
# 3        Nashville    TN  37207.0
# 4       Crossville    TN  38555.0
# ..             ...   ...      ...
# 75         Lebanon    TN  37087.0
# 76  Hendersonville    TN  37075.0
# 77       Nashville    TN  37211.0
# 78          Smyrna    TN  37167.0
# 79             NaN   NaN      NaN
#
# [80 rows x 5 columns]

# %%
outpatient_tmp.tail(47339)
# Out:
#                                full_name                   address    city  \
# 78     Tristar Stonecrest Medical Center  200 Stonecrest Boulevard  Smyrna
# 79                                   NaN                       NaN     NaN
# 80                                   NaN                       NaN     NaN
# 81                                   NaN                       NaN     NaN
# 82                                   NaN                       NaN     NaN
# ...                                  ...                       ...     ...
# 47412                                NaN                       NaN     NaN
# 47413                                NaN                       NaN     NaN
# 47414                                NaN                       NaN     NaN
# 47415                                NaN                       NaN     NaN
# 47416                                NaN                       NaN     NaN
#
#       state      zip
# 78       TN  37167.0
# 79      NaN      NaN
# 80      NaN      NaN
# 81      NaN      NaN
# 82      NaN      NaN
# ...     ...      ...
# 47412   NaN      NaN
# 47413   NaN      NaN
# 47414   NaN      NaN
# 47415   NaN      NaN
# 47416   NaN      NaN
#
# [47339 rows x 5 columns]

# %%
# drop NaN columns
outpatient_tmp.dropna()
# Out:
#                                   full_name                    address  \
# 0   Jackson-Madison County General Hospital          620 Skyline Drive
# 1   Jackson-Madison County General Hospital          620 Skyline Drive
# 2            Sumner Regional Medical Center        555 Hartsville Pike
# 3            Tristar Skyline Medical Center        3441 Dickerson Pike
# 4                 Cumberland Medical Center              421 S Main St
# ..                                      ...                        ...
# 74          Saint Thomas Highlands Hospital              401 Sewell Dr
# 75               Tennova Healthcare-Lebanon       1411 Baddour Parkway
# 76    Tristar Hendersonville Medical Center  355 New Shackle Island Rd
# 77    Tristar Southern Hills Medical Center             391 Wallace Rd
# 78        Tristar Stonecrest Medical Center   200 Stonecrest Boulevard
#
#               city state      zip
# 0          Jackson    TN  38301.0
# 1          Jackson    TN  38301.0
# 2         Gallatin    TN  37066.0
# 3        Nashville    TN  37207.0
# 4       Crossville    TN  38555.0
# ..             ...   ...      ...
# 74          Sparta    TN  38583.0
# 75         Lebanon    TN  37087.0
# 76  Hendersonville    TN  37075.0
# 77       Nashville    TN  37211.0
# 78          Smyrna    TN  37167.0
#
# [79 rows x 5 columns]

# %%
# drop duplicates
outpatient_tmp = outpatient_tmp.drop_duplicates(keep=False)
outpatient_tmp
# Out:
#                                             full_name  \
# 2                      Sumner Regional Medical Center
# 3                      Tristar Skyline Medical Center
# 4                           Cumberland Medical Center
# 5                            Blount Memorial Hospital
# 6            Wellmont Bristol Regional Medical Center
# 9              Wellmont Holston Valley Medical Center
# 14                          Williamson Medical Center
# 15            Morristown Hamblen Hospital Association
# 16                          Lakeway Regional Hospital
# 17                               Roane Medical Center
# 18        Tennova Healthcare-Lafollett Medical Center
# 19              Methodist Medical Center Of Oak Ridge
# 20                     Tennova Healthcare-Clarksville
# 21               Vanderbilt University Medical Center
# 24                          Baptist Memorial Hospital
# 25             Methodist Healthcare Memphis Hospitals
# 28                   Saint Thomas Rutherford Hospital
# 29                           Claiborne Medical Center
# 30  Southern Tennessee Regional Hlth System Winche...
# 31                 Cookeville Regional Medical Center
# 36                        Johnson City Medical Center
# 37                          Northcrest Medical Center
# 38               Starr Regional Medical Center Athens
# 39              Tennova Healthcare-Dyersburg Regional
# 42                         Saint Thomas West Hospital
# 43                     Tennova Healthcare - Jamestown
# 47                    Memorial Healthcare System, Inc
# 48                           Parkridge Medical Center
# 52                            Erlanger Medical Center
# 53                              Hardin Medical Center
# 54                         Fort Loudon Medical Center
# 55                   Metro Nashville General Hospital
# 56                                 Tennova Healthcare
# 57               Fort Sanders Regional Medical Center
# 62                      Saint Thomas Midtown Hospital
# 65                      Tristar Summit Medical Center
# 66                  Tristar Centennial Medical Center
# 67                            Parkwest Medical Center
# 75                         Tennova Healthcare-Lebanon
# 76              Tristar Hendersonville Medical Center
# 77              Tristar Southern Hills Medical Center
# 78                  Tristar Stonecrest Medical Center
#
#                               address            city state      zip
# 2                 555 Hartsville Pike        Gallatin    TN  37066.0
# 3                 3441 Dickerson Pike       Nashville    TN  37207.0
# 4                       421 S Main St      Crossville    TN  38555.0
# 5       907 E Lamar Alexander Parkway       Maryville    TN  37804.0
# 6               One Medical Park Blvd         Bristol    TN  37620.0
# 9                130 West Ravine Road       Kingsport    TN  37662.0
# 14             4321 Carothers Parkway        Franklin    TN  37067.0
# 15                 908 W 4th North St      Morristown    TN  37814.0
# 16                   726 Mcfarland St      Morristown    TN  37814.0
# 17    8045 Roane Medical Center Drive        Harriman    TN  37748.0
# 18            923 East Central Avenue     La Follette    TN  37766.0
# 19     990 Oak Ridge Turnpike Box 529       Oak Ridge    TN  37830.0
# 20                    651 Dunlop Lane     Clarksville    TN  37040.0
# 21          1211 Medical Center Drive       Nashville    TN  37232.0
# 24             6019 Walnut Grove Road         Memphis    TN  38120.0
# 25           1265 Union Ave Suite 700         Memphis    TN  38104.0
# 28        1700 Medical Center Parkway    Murfreesboro    TN  37129.0
# 29         1850 Old Knoxville Highway        Tazewell    TN  37879.0
# 30                  185 Hospital Road      Winchester    TN  37398.0
# 31         1 Medical Center Boulevard      Cookeville    TN  38501.0
# 36         400 N State Of Franklin Rd    Johnson City    TN  37604.0
# 37               100 Northcrest Drive     Springfield    TN  37172.0
# 38                 1114 W Madison Ave          Athens    TN  37371.0
# 39                      400 Tickle St       Dyersburg    TN  38024.0
# 42        4220 Harding Rd, Po Box 380       Nashville    TN  37205.0
# 43            436 Central Avenue West       Jamestown    TN  38556.0
# 47                   2525 Desales Ave     Chattanooga    TN  37404.0
# 48                  2333 Mccallie Ave     Chattanooga    TN  37404.0
# 52                       975 E 3rd St     Chattanooga    TN  37403.0
# 53                     935 Wayne Road        Savannah    TN  38372.0
# 54  550 Fort Loudon Medical Center Dr     Lenoir City    TN  37772.0
# 55                 1818 Albion Street       Nashville    TN  37208.0
# 56           900 East Oak Hill Avenue       Knoxville    TN  37917.0
# 57                  1901 W Clinch Ave       Knoxville    TN  37916.0
# 62                     2000 Church St       Nashville    TN  37236.0
# 65                    5655 Frist Blvd       Hermitage    TN  37076.0
# 66              2300 Patterson Street       Nashville    TN  37203.0
# 67                9352 Park West Blvd       Knoxville    TN  37923.0
# 75               1411 Baddour Parkway         Lebanon    TN  37087.0
# 76          355 New Shackle Island Rd  Hendersonville    TN  37075.0
# 77                     391 Wallace Rd       Nashville    TN  37211.0
# 78           200 Stonecrest Boulevard          Smyrna    TN  37167.0

# %%
# save this version of outpatient_tmp for later
# outpatient_providers = outpatient_tmp.drop(['apc','apc_description'], axis=1)

outpatient_providers = outpatient_tmp

# save_me
outpatient_providers.to_csv('../data/clean/outpatient_providers.csv')

# %%
# tennessee providers has NaNs in the full_name field. Fix them.
tennessee_providers['full_name'].fillna(tennessee_providers['last_name'], inplace = True) 

# confirm that there are no NaNs in the full_name field. Ok to have them in other fields
null_columns=tennessee_providers.columns[tennessee_providers.isnull().any()]
tennessee_providers[null_columns].isnull().sum()
# Out:
# first_name      38
# address2      1283
# dtype: int64

# %%
# drop first_ and last_name from tennessee_providers, will only use full_name
tennessee_providers = tennessee_providers.drop(['first_name', 'last_name'], axis=1)

tennessee_providers
# Out:
#                            address   address2          city state        zip  \
# 6354             1700 carmack blvd        NaN      Columbia    TN      38401
# 15768      214 west longview drive        NaN      Portland    TN      37148
# 17080    1222 trotwood ave ste 603        NaN      Columbia    TN      38401
# 26250          1 medical park blvd        NaN       Bristol    TN  376207430
# 27899               3310 w end ave  Suite 590     Nashville    TN  372031028
# ...                            ...        ...           ...   ...        ...
# 9834934               975 e 3rd st        NaN   Chattanooga    TN  374032147
# 9834942            713 cheatham st        NaN   Springfield    TN  371722828
# 9839309          317 n hickory ave        NaN    Cookeville    TN  385012428
# 9840208          5301 virginia way  Suite 300     Brentwood    TN  370277541
# 9841223      1124 new highway 52 e        NaN  Westmoreland    TN  371865060
#
#                   full_name
# 6354            Ralph Stone
# 15768    State of tennessee
# 17080         Patrick Davis
# 26250        Cassondra Horn
# 27899           Emily Hiatt
# ...                     ...
# 9834934        Jasmine Shah
# 9834942         Marie Basty
# 9839309         Amanda Bell
# 9840208        Farrukh Gill
# 9841223        Amanda Perry
#
# [1997 rows x 6 columns]

# %%
tennessee_providers.address.value_counts()
# Out:
# 110 29th ave n                43
# 3601 tvc                      38
# 3601 the vanderbilt clinic    35
# 110 29th ave n ste 202        25
# 501 20th st                   22
#                               ..
# 2000 old fort pkwy             1
# 114 highway 70 e               1
# 1112 nashville pike            1
# 105 cherokee rd                1
# 6000 ramsey way                1
# Name: address, Length: 1361, dtype: int64

# %%
# extract addresses from tennessee_providers for geocoding
tennessee_providers_addresses = tennessee_providers[['address', 'city', 'state', 'zip']]

tennessee_providers_addresses
# Out:
#                            address          city state        zip
# 6354             1700 carmack blvd      Columbia    TN      38401
# 15768      214 west longview drive      Portland    TN      37148
# 17080    1222 trotwood ave ste 603      Columbia    TN      38401
# 26250          1 medical park blvd       Bristol    TN  376207430
# 27899               3310 w end ave     Nashville    TN  372031028
# ...                            ...           ...   ...        ...
# 9834934               975 e 3rd st   Chattanooga    TN  374032147
# 9834942            713 cheatham st   Springfield    TN  371722828
# 9839309          317 n hickory ave    Cookeville    TN  385012428
# 9840208          5301 virginia way     Brentwood    TN  370277541
# 9841223      1124 new highway 52 e  Westmoreland    TN  371865060
#
# [1997 rows x 4 columns]

# %%
# save these versions of tennessee_providers_addresses and tennessee_providers for later
tennessee_providers_addresses.to_csv('../data/clean/tennessee_providers_addresses.csv')
tennessee_providers.to_csv('../data/clean/tennessee_providers.csv')

# %%
# hey, stop here
# get geocodes for tennessee_providers_addresses, then clean up results file in BBEdit … 
#     will need to remove double quotes around each value and add names to columns w/o them

# %% [markdown]
# ## Import and Join Geocodes to DataFrames

# %%
# NOTE: outpatient_geocoded_addresses does not include the three public clinics in davidson County. 
# I added them manually 
#     42	East Public Health Center	1015 East Trinity Lane	Nashville	TN		Nashville	TN		-86.745286	36.204273
#     43	Woodbine Public Health Center	224 Oriel Avenue	Nashville	TN		Nashville	TN		-86.743627	36.122097
#     44	Lentz Public Health Center	2500 Charlotte Avenue	Nashville	TN		Nashville	TN		-86.812991	36.155043

# %%
# set up import variables

# import geocoded address files for joining
tennessee_providers_geocodes_csv = '../data/location/tennessee_providers_geocoded_addresses.csv'
outpatient_geocodes_csv = '../data/clean/all_providers_geocodes.csv'
# outpatient_geocodes_csv = '../data/clean/outpatient_geocodes.csv'   # Not sure what this file was for


# import only the needed columns from outpatient_geocodes
columns = ['address', ' city', ' state', ' zip', 'longitude', 'latitude'] 
# import file to create dataframe
outpatient_geocodes = pd.read_csv(outpatient_geocodes_csv, usecols=columns)
# delete initial space in column names
outpatient_geocodes.columns = outpatient_geocodes.columns.str.replace(' ', '').str.lower()


# repeat for tennessee_providers_geocodes, note lack of leading space in column names
columns = ['address', 'city', 'state', 'zip', 'longitude', 'latitude'] 
tennessee_providers_geocodes = pd.read_csv(tennessee_providers_geocodes_csv, usecols=columns)


# confirm imports
print('This is outpatient with geocodes')
print(outpatient_geocodes.info())
print('This is tennessee_providers with geocodes')
print(tennessee_providers_geocodes.info())
# Out:
# This is outpatient with geocodes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806 entries, 0 to 805
# Data columns (total 6 columns):
# address      806 non-null object
# city         806 non-null object
# state        806 non-null object
# zip          806 non-null int64
# longitude    576 non-null float64
# latitude     576 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 37.9+ KB
# None
# This is tennessee_providers with geocodes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1997 entries, 0 to 1996
# Data columns (total 6 columns):
# address      1997 non-null object
# city         1997 non-null object
# state        1997 non-null object
# zip          1996 non-null float64
# longitude    1461 non-null float64
# latitude     1462 non-null float64
# dtypes: float64(3), object(3)
# memory usage: 93.7+ KB
# None

# %%
# join outpatient files
# note, if I include 'city', 'state', 'zip' in my join, I don't get longitude and latitude
#     Joining on 'address' only give more complete results. Only two Nashville addresses w/o longitude and latitude

outpatient_locations = pd.merge(outpatient_tmp, outpatient_geocodes, how='left', on=['address'])

outpatient_locations.tail(50)
# Out:
#                                             full_name  \
# 0                      Sumner Regional Medical Center
# 1                      Tristar Skyline Medical Center
# 2                           Cumberland Medical Center
# 3                            Blount Memorial Hospital
# 4            Wellmont Bristol Regional Medical Center
# 5              Wellmont Holston Valley Medical Center
# 6                           Williamson Medical Center
# 7             Morristown Hamblen Hospital Association
# 8                           Lakeway Regional Hospital
# 9                                Roane Medical Center
# 10        Tennova Healthcare-Lafollett Medical Center
# 11              Methodist Medical Center Of Oak Ridge
# 12                     Tennova Healthcare-Clarksville
# 13               Vanderbilt University Medical Center
# 14                          Baptist Memorial Hospital
# 15             Methodist Healthcare Memphis Hospitals
# 16                   Saint Thomas Rutherford Hospital
# 17                           Claiborne Medical Center
# 18  Southern Tennessee Regional Hlth System Winche...
# 19                 Cookeville Regional Medical Center
# 20                        Johnson City Medical Center
# 21                          Northcrest Medical Center
# 22               Starr Regional Medical Center Athens
# 23              Tennova Healthcare-Dyersburg Regional
# 24                         Saint Thomas West Hospital
# 25                     Tennova Healthcare - Jamestown
# 26                    Memorial Healthcare System, Inc
# 27                           Parkridge Medical Center
# 28                            Erlanger Medical Center
# 29                              Hardin Medical Center
# 30                         Fort Loudon Medical Center
# 31                   Metro Nashville General Hospital
# 32                                 Tennova Healthcare
# 33               Fort Sanders Regional Medical Center
# 34                      Saint Thomas Midtown Hospital
# 35                      Tristar Summit Medical Center
# 36                  Tristar Centennial Medical Center
# 37                            Parkwest Medical Center
# 38                         Tennova Healthcare-Lebanon
# 39              Tristar Hendersonville Medical Center
# 40              Tristar Southern Hills Medical Center
# 41                  Tristar Stonecrest Medical Center
#
#                               address          city_x state_x    zip_x  \
# 0                 555 Hartsville Pike        Gallatin      TN  37066.0
# 1                 3441 Dickerson Pike       Nashville      TN  37207.0
# 2                       421 S Main St      Crossville      TN  38555.0
# 3       907 E Lamar Alexander Parkway       Maryville      TN  37804.0
# 4               One Medical Park Blvd         Bristol      TN  37620.0
# 5                130 West Ravine Road       Kingsport      TN  37662.0
# 6              4321 Carothers Parkway        Franklin      TN  37067.0
# 7                  908 W 4th North St      Morristown      TN  37814.0
# 8                    726 Mcfarland St      Morristown      TN  37814.0
# 9     8045 Roane Medical Center Drive        Harriman      TN  37748.0
# 10            923 East Central Avenue     La Follette      TN  37766.0
# 11     990 Oak Ridge Turnpike Box 529       Oak Ridge      TN  37830.0
# 12                    651 Dunlop Lane     Clarksville      TN  37040.0
# 13          1211 Medical Center Drive       Nashville      TN  37232.0
# 14             6019 Walnut Grove Road         Memphis      TN  38120.0
# 15           1265 Union Ave Suite 700         Memphis      TN  38104.0
# 16        1700 Medical Center Parkway    Murfreesboro      TN  37129.0
# 17         1850 Old Knoxville Highway        Tazewell      TN  37879.0
# 18                  185 Hospital Road      Winchester      TN  37398.0
# 19         1 Medical Center Boulevard      Cookeville      TN  38501.0
# 20         400 N State Of Franklin Rd    Johnson City      TN  37604.0
# 21               100 Northcrest Drive     Springfield      TN  37172.0
# 22                 1114 W Madison Ave          Athens      TN  37371.0
# 23                      400 Tickle St       Dyersburg      TN  38024.0
# 24        4220 Harding Rd, Po Box 380       Nashville      TN  37205.0
# 25            436 Central Avenue West       Jamestown      TN  38556.0
# 26                   2525 Desales Ave     Chattanooga      TN  37404.0
# 27                  2333 Mccallie Ave     Chattanooga      TN  37404.0
# 28                       975 E 3rd St     Chattanooga      TN  37403.0
# 29                     935 Wayne Road        Savannah      TN  38372.0
# 30  550 Fort Loudon Medical Center Dr     Lenoir City      TN  37772.0
# 31                 1818 Albion Street       Nashville      TN  37208.0
# 32           900 East Oak Hill Avenue       Knoxville      TN  37917.0
# 33                  1901 W Clinch Ave       Knoxville      TN  37916.0
# 34                     2000 Church St       Nashville      TN  37236.0
# 35                    5655 Frist Blvd       Hermitage      TN  37076.0
# 36              2300 Patterson Street       Nashville      TN  37203.0
# 37                9352 Park West Blvd       Knoxville      TN  37923.0
# 38               1411 Baddour Parkway         Lebanon      TN  37087.0
# 39          355 New Shackle Island Rd  Hendersonville      TN  37075.0
# 40                     391 Wallace Rd       Nashville      TN  37211.0
# 41           200 Stonecrest Boulevard          Smyrna      TN  37167.0
#
#              city_y state_y    zip_y  longitude   latitude
# 0          Gallatin      TN  37066.0        NaN        NaN
# 1         Nashville      TN  37207.0        NaN        NaN
# 2        Crossville      TN  38555.0        NaN        NaN
# 3         Maryville      TN  37804.0 -83.959100  35.754974
# 4           Bristol      TN  37620.0        NaN        NaN
# 5         Kingsport      TN  37662.0        NaN        NaN
# 6          Franklin      TN  37067.0 -86.816950  35.917603
# 7        Morristown      TN  37814.0 -83.304390  36.211937
# 8        Morristown      TN  37814.0 -83.304310  36.214622
# 9          Harriman      TN  37748.0 -84.555176  35.889380
# 10      La Follette      TN  37766.0        NaN        NaN
# 11        Oak Ridge      TN  37830.0        NaN        NaN
# 12      Clarksville      TN  37040.0 -87.270070  36.579998
# 13        Nashville      TN  37232.0        NaN        NaN
# 14          Memphis      TN  38120.0        NaN        NaN
# 15          Memphis      TN  38104.0 -90.019356  35.137104
# 16     Murfreesboro      TN  37129.0 -86.421070  35.860270
# 17         Tazewell      TN  37879.0        NaN        NaN
# 18       Winchester      TN  37398.0 -86.091080  35.176003
# 19       Cookeville      TN  38501.0 -85.509520  36.170155
# 20     Johnson City      TN  37604.0 -82.386536  36.308666
# 21      Springfield      TN  37172.0        NaN        NaN
# 22           Athens      TN  37371.0        NaN        NaN
# 23        Dyersburg      TN  38024.0 -89.380910  36.047314
# 24              NaN     NaN      NaN        NaN        NaN
# 25        Jamestown      TN  38556.0        NaN        NaN
# 26      Chattanooga      TN  37404.0 -85.261410  35.040160
# 27      Chattanooga      TN  37404.0 -85.267570  35.033268
# 28      Chattanooga      TN  37403.0        NaN        NaN
# 29         Savannah      TN  38372.0 -88.230570  35.227165
# 30      Lenoir City      TN  37772.0 -84.271164  35.825400
# 31        Nashville      TN  37208.0 -86.805620  36.166256
# 32        Knoxville      TN  37917.0        NaN        NaN
# 33        Knoxville      TN  37916.0 -83.936325  35.957134
# 34        Nashville      TN  37236.0 -86.800990  36.153330
# 35        Hermitage      TN  37076.0        NaN        NaN
# 36        Nashville      TN  37203.0 -86.809600  36.151870
# 37        Knoxville      TN  37923.0 -84.098656  35.918390
# 38          Lebanon      TN  37087.0 -86.328500  36.219234
# 39   Hendersonville      TN  37075.0 -86.620030  36.322113
# 40        Nashville      TN  37211.0 -86.723170  36.078094
# 41           Smyrna      TN  37167.0 -86.563990  35.972836

# %%
# export geocoded outpatient addresses
outpatient_locations.to_csv('../data/clean/outpatient_geocoded_addresses.csv')

# %%
# join tennessee_providers files
# note, if I include 'city', 'state', 'zip' in my join, I don't get longitude and latitude
#     Joining on 'address' only give more complete results. Only two Nashville addresses w/o longitude and latitude
result = pd.merge(tennessee_providers, tennessee_providers_geocodes, how='left', on=['address'])

result.head(50)
# Out:
#                         address    address2        city_x state_x      zip_x  \
# 0             1700 carmack blvd         NaN      Columbia      TN      38401
# 1       214 west longview drive         NaN      Portland      TN      37148
# 2     1222 trotwood ave ste 603         NaN      Columbia      TN      38401
# 3           1 medical park blvd         NaN       Bristol      TN  376207430
# 4           1 medical park blvd         NaN       Bristol      TN  376207430
# 5           1 medical park blvd         NaN       Bristol      TN  376207430
# 6           1 medical park blvd         NaN       Bristol      TN  376207430
# 7           1 medical park blvd         NaN       Bristol      TN  376207430
# 8           1 medical park blvd         NaN       Bristol      TN  376207430
# 9           1 medical park blvd         NaN       Bristol      TN  376207430
# 10          1 medical park blvd         NaN       Bristol      TN  376207430
# 11          1 medical park blvd         NaN       Bristol      TN  376207430
# 12          1 medical park blvd         NaN       Bristol      TN  376207430
# 13          1 medical park blvd         NaN       Bristol      TN  376207430
# 14          1 medical park blvd         NaN       Bristol      TN  376207430
# 15          1 medical park blvd         NaN       Bristol      TN  376207430
# 16          1 medical park blvd         NaN       Bristol      TN  376207430
# 17          1 medical park blvd         NaN       Bristol      TN  376207430
# 18               3310 w end ave   Suite 590     Nashville      TN  372031028
# 19       1740 n germantown pkwy    Suite #6       Cordova      TN  380163307
# 20  6031 shallowford rd ste 117         NaN   Chattanooga      TN  374211984
# 21                5039 park ave   Suite 102       Memphis      TN  381175701
# 22   325 n state of franklin rd         NaN  Johnson city      TN      37604
# 23   325 n state of franklin rd         NaN  Johnson city      TN      37604
# 24   325 n state of franklin rd         NaN  Johnson city      TN      37604
# 25   325 n state of franklin rd         NaN  Johnson city      TN      37604
# 26   325 n state of franklin rd         NaN  Johnson city      TN      37604
# 27   325 n state of franklin rd         NaN  Johnson city      TN      37604
# 28          9330 park west blvd   Suite 108     Knoxville      TN  379234308
# 29          9330 park west blvd   Suite 108     Knoxville      TN  379234308
# 30              3183 w state st  Suite 1201       Bristol      TN  376201712
# 31               110 29th ave n     Ste 202     Nashville      TN  372031401
# 32               110 29th ave n     Ste 202     Nashville      TN  372031401
# 33               110 29th ave n     Ste 202     Nashville      TN  372031401
# 34               110 29th ave n     Ste 202     Nashville      TN  372031401
# 35               110 29th ave n     Ste 202     Nashville      TN  372031401
# 36               110 29th ave n     Ste 202     Nashville      TN  372031401
# 37               110 29th ave n     Ste 202     Nashville      TN  372031401
# 38               110 29th ave n     Ste 202     Nashville      TN  372031401
# 39               110 29th ave n     Ste 202     Nashville      TN  372031401
# 40               110 29th ave n     Ste 202     Nashville      TN  372031401
# 41               110 29th ave n     Ste 202     Nashville      TN  372031401
# 42               110 29th ave n     Ste 202     Nashville      TN  372031401
# 43               110 29th ave n     Ste 202     Nashville      TN  372031401
# 44               110 29th ave n     Ste 202     Nashville      TN  372031401
# 45               110 29th ave n     Ste 202     Nashville      TN  372031401
# 46               110 29th ave n     Ste 202     Nashville      TN  372031401
# 47               110 29th ave n     Ste 202     Nashville      TN  372031401
# 48               110 29th ave n     Ste 202     Nashville      TN  372031401
# 49               110 29th ave n     Ste 202     Nashville      TN  372031401
#
#              full_name         city_y state_y        zip_y  longitude  \
# 0          Ralph Stone       Columbia      TN      38401.0        NaN
# 1   State of tennessee       Portland      TN      37148.0 -86.515460
# 2        Patrick Davis       Columbia      TN      38401.0 -87.065560
# 3       Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 4       Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 5       Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 6       Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 7       Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 8       Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 9       Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 10      Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 11      Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 12      Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 13      Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 14      Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 15      Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 16      Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 17      Cassondra Horn        Bristol      TN  376207430.0 -82.253800
# 18         Emily Hiatt      Nashville      TN  372031028.0 -86.817690
# 19       Charles Hogan        Cordova      TN  380163307.0 -89.792910
# 20      Brittany Pryor    Chattanooga      TN  374211984.0 -85.188446
# 21        Laura Vaughn        Memphis      TN  381175701.0 -89.893960
# 22        Martin Olsen   Johnson city      TN  376046062.0 -82.386490
# 23        Martin Olsen   Johnson city      TN      37604.0 -82.386490
# 24        Martin Olsen   Johnson city      TN      37604.0 -82.386490
# 25        Martin Olsen   Johnson city      TN  376046062.0 -82.386490
# 26        Martin Olsen   Johnson city      TN  376046056.0 -82.386490
# 27        Martin Olsen   Johnson city      TN      37614.0        NaN
# 28      Brent Grishkin      Knoxville      TN  379234308.0 -84.098040
# 29      Brent Grishkin      Knoxville      TN  379234308.0 -84.098040
# 30       Steven Morgan        Bristol      TN  376201712.0 -82.238360
# 31         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 32         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 33         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 34         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 35         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 36         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 37         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 38         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 39         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 40         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 41         Misty Handy      Nashville      TN      37203.0 -86.813620
# 42         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 43         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 44         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 45         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 46         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 47         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 48         Misty Handy      Nashville      TN  372031401.0 -86.813620
# 49         Misty Handy      Nashville      TN  372031401.0 -86.813620
#
#      latitude
# 0         NaN
# 1   36.560825
# 2   35.606100
# 3   36.589270
# 4   36.589270
# 5   36.589270
# 6   36.589270
# 7   36.589270
# 8   36.589270
# 9   36.589270
# 10  36.589270
# 11  36.589270
# 12  36.589270
# 13  36.589270
# 14  36.589270
# 15  36.589270
# 16  36.589270
# 17  36.589270
# 18  36.140644
# 19  35.173042
# 20  35.053970
# 21  35.106540
# 22  36.306812
# 23  36.306812
# 24  36.306812
# 25  36.306812
# 26  36.306812
# 27        NaN
# 28  35.918430
# 29  35.918430
# 30  36.591890
# 31  36.145176
# 32  36.145176
# 33  36.145176
# 34  36.145176
# 35  36.145176
# 36  36.145176
# 37  36.145176
# 38  36.145176
# 39  36.145176
# 40  36.145176
# 41  36.145176
# 42  36.145176
# 43  36.145176
# 44  36.145176
# 45  36.145176
# 46  36.145176
# 47  36.145176
# 48  36.145176
# 49  36.145176

# %%
# drop duplicates
tennessee_providers = result.drop_duplicates(keep=False)
tennessee_providers
# Out:
#                           address   address2        city_x state_x      zip_x  \
# 0               1700 carmack blvd        NaN      Columbia      TN      38401
# 1         214 west longview drive        NaN      Portland      TN      37148
# 2       1222 trotwood ave ste 603        NaN      Columbia      TN      38401
# 18                 3310 w end ave  Suite 590     Nashville      TN  372031028
# 19         1740 n germantown pkwy   Suite #6       Cordova      TN  380163307
# ...                           ...        ...           ...     ...        ...
# 10074  3601 the vanderbilt clinic        NaN     Nashville      TN  372320014
# 10101                975 e 3rd st        NaN   Chattanooga      TN  374032147
# 10102                975 e 3rd st        NaN   Chattanooga      TN  374032147
# 10109           5301 virginia way  Suite 300     Brentwood      TN  370277541
# 10110       1124 new highway 52 e        NaN  Westmoreland      TN  371865060
#
#                 full_name         city_y state_y        zip_y  longitude  \
# 0             Ralph Stone       Columbia      TN      38401.0        NaN
# 1      State of tennessee       Portland      TN      37148.0  -86.51546
# 2           Patrick Davis       Columbia      TN      38401.0  -87.06556
# 18            Emily Hiatt      Nashville      TN  372031028.0  -86.81769
# 19          Charles Hogan        Cordova      TN  380163307.0  -89.79291
# ...                   ...            ...     ...          ...        ...
# 10074      Tiffany Street      Nashville      TN  372322012.0        NaN
# 10101        Jasmine Shah    Chattanooga      TN  374032103.0        NaN
# 10102        Jasmine Shah    Chattanooga      TN      37403.0        NaN
# 10109        Farrukh Gill      Brentwood      TN  370277541.0  -86.80924
# 10110        Amanda Perry   Westmoreland      TN  371865060.0        NaN
#
#         latitude
# 0            NaN
# 1      36.560825
# 2      35.606100
# 18     36.140644
# 19     35.173042
# ...          ...
# 10074        NaN
# 10101        NaN
# 10102        NaN
# 10109  36.032856
# 10110        NaN
#
# [1790 rows x 11 columns]

# %%
# export geocoded outpatient addresses
tennessee_providers.to_csv('../data/clean/tennessee_providers_geocoded_addresses.csv')

# %%
# hey, stop here

# %%
# join temp dataframes so that all providers are in one geocoded file
all_providers = outpatient_locations.append(tennessee_providers)

# fix column names
all_providers.columns = ['address', 'address2', 'city', 'city_y', 'full_name', 'latitude', 'longitude', 
           'state', 'state_y', 'zip', 'zip_y']
# drop extra columns
all_providers = all_providers.drop(['city_y', 'state_y', 'zip_y'], axis=1)
all_providers.head(50)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#                               address   address2            city  \
# 0                 555 Hartsville Pike        NaN        Gallatin
# 1                 3441 Dickerson Pike        NaN       Nashville
# 2                       421 S Main St        NaN      Crossville
# 3       907 E Lamar Alexander Parkway        NaN       Maryville
# 4               One Medical Park Blvd        NaN         Bristol
# 5                130 West Ravine Road        NaN       Kingsport
# 6              4321 Carothers Parkway        NaN        Franklin
# 7                  908 W 4th North St        NaN      Morristown
# 8                    726 Mcfarland St        NaN      Morristown
# 9     8045 Roane Medical Center Drive        NaN        Harriman
# 10            923 East Central Avenue        NaN     La Follette
# 11     990 Oak Ridge Turnpike Box 529        NaN       Oak Ridge
# 12                    651 Dunlop Lane        NaN     Clarksville
# 13          1211 Medical Center Drive        NaN       Nashville
# 14             6019 Walnut Grove Road        NaN         Memphis
# 15           1265 Union Ave Suite 700        NaN         Memphis
# 16        1700 Medical Center Parkway        NaN    Murfreesboro
# 17         1850 Old Knoxville Highway        NaN        Tazewell
# 18                  185 Hospital Road        NaN      Winchester
# 19         1 Medical Center Boulevard        NaN      Cookeville
# 20         400 N State Of Franklin Rd        NaN    Johnson City
# 21               100 Northcrest Drive        NaN     Springfield
# 22                 1114 W Madison Ave        NaN          Athens
# 23                      400 Tickle St        NaN       Dyersburg
# 24        4220 Harding Rd, Po Box 380        NaN       Nashville
# 25            436 Central Avenue West        NaN       Jamestown
# 26                   2525 Desales Ave        NaN     Chattanooga
# 27                  2333 Mccallie Ave        NaN     Chattanooga
# 28                       975 E 3rd St        NaN     Chattanooga
# 29                     935 Wayne Road        NaN        Savannah
# 30  550 Fort Loudon Medical Center Dr        NaN     Lenoir City
# 31                 1818 Albion Street        NaN       Nashville
# 32           900 East Oak Hill Avenue        NaN       Knoxville
# 33                  1901 W Clinch Ave        NaN       Knoxville
# 34                     2000 Church St        NaN       Nashville
# 35                    5655 Frist Blvd        NaN       Hermitage
# 36              2300 Patterson Street        NaN       Nashville
# 37                9352 Park West Blvd        NaN       Knoxville
# 38               1411 Baddour Parkway        NaN         Lebanon
# 39          355 New Shackle Island Rd        NaN  Hendersonville
# 40                     391 Wallace Rd        NaN       Nashville
# 41           200 Stonecrest Boulevard        NaN          Smyrna
# 0                   1700 carmack blvd        NaN        Columbia
# 1             214 west longview drive        NaN        Portland
# 2           1222 trotwood ave ste 603        NaN        Columbia
# 18                     3310 w end ave  Suite 590       Nashville
# 19             1740 n germantown pkwy   Suite #6         Cordova
# 20        6031 shallowford rd ste 117        NaN     Chattanooga
# 21                      5039 park ave  Suite 102         Memphis
# 26         325 n state of franklin rd        NaN    Johnson city
#
#                                             full_name   latitude  longitude  \
# 0                      Sumner Regional Medical Center        NaN        NaN
# 1                      Tristar Skyline Medical Center        NaN        NaN
# 2                           Cumberland Medical Center        NaN        NaN
# 3                            Blount Memorial Hospital  35.754974 -83.959100
# 4            Wellmont Bristol Regional Medical Center        NaN        NaN
# 5              Wellmont Holston Valley Medical Center        NaN        NaN
# 6                           Williamson Medical Center  35.917603 -86.816950
# 7             Morristown Hamblen Hospital Association  36.211937 -83.304390
# 8                           Lakeway Regional Hospital  36.214622 -83.304310
# 9                                Roane Medical Center  35.889380 -84.555176
# 10        Tennova Healthcare-Lafollett Medical Center        NaN        NaN
# 11              Methodist Medical Center Of Oak Ridge        NaN        NaN
# 12                     Tennova Healthcare-Clarksville  36.579998 -87.270070
# 13               Vanderbilt University Medical Center        NaN        NaN
# 14                          Baptist Memorial Hospital        NaN        NaN
# 15             Methodist Healthcare Memphis Hospitals  35.137104 -90.019356
# 16                   Saint Thomas Rutherford Hospital  35.860270 -86.421070
# 17                           Claiborne Medical Center        NaN        NaN
# 18  Southern Tennessee Regional Hlth System Winche...  35.176003 -86.091080
# 19                 Cookeville Regional Medical Center  36.170155 -85.509520
# 20                        Johnson City Medical Center  36.308666 -82.386536
# 21                          Northcrest Medical Center        NaN        NaN
# 22               Starr Regional Medical Center Athens        NaN        NaN
# 23              Tennova Healthcare-Dyersburg Regional  36.047314 -89.380910
# 24                         Saint Thomas West Hospital        NaN        NaN
# 25                     Tennova Healthcare - Jamestown        NaN        NaN
# 26                    Memorial Healthcare System, Inc  35.040160 -85.261410
# 27                           Parkridge Medical Center  35.033268 -85.267570
# 28                            Erlanger Medical Center        NaN        NaN
# 29                              Hardin Medical Center  35.227165 -88.230570
# 30                         Fort Loudon Medical Center  35.825400 -84.271164
# 31                   Metro Nashville General Hospital  36.166256 -86.805620
# 32                                 Tennova Healthcare        NaN        NaN
# 33               Fort Sanders Regional Medical Center  35.957134 -83.936325
# 34                      Saint Thomas Midtown Hospital  36.153330 -86.800990
# 35                      Tristar Summit Medical Center        NaN        NaN
# 36                  Tristar Centennial Medical Center  36.151870 -86.809600
# 37                            Parkwest Medical Center  35.918390 -84.098656
# 38                         Tennova Healthcare-Lebanon  36.219234 -86.328500
# 39              Tristar Hendersonville Medical Center  36.322113 -86.620030
# 40              Tristar Southern Hills Medical Center  36.078094 -86.723170
# 41                  Tristar Stonecrest Medical Center  35.972836 -86.563990
# 0                                         Ralph Stone        NaN        NaN
# 1                                  State of tennessee  36.560825 -86.515460
# 2                                       Patrick Davis  35.606100 -87.065560
# 18                                        Emily Hiatt  36.140644 -86.817690
# 19                                      Charles Hogan  35.173042 -89.792910
# 20                                     Brittany Pryor  35.053970 -85.188446
# 21                                       Laura Vaughn  35.106540 -89.893960
# 26                                       Martin Olsen  36.306812 -82.386490
#
#    state          zip
# 0     TN      37066.0
# 1     TN      37207.0
# 2     TN      38555.0
# 3     TN      37804.0
# 4     TN      37620.0
# 5     TN      37662.0
# 6     TN      37067.0
# 7     TN      37814.0
# 8     TN      37814.0
# 9     TN      37748.0
# 10    TN      37766.0
# 11    TN      37830.0
# 12    TN      37040.0
# 13    TN      37232.0
# 14    TN      38120.0
# 15    TN      38104.0
# 16    TN      37129.0
# 17    TN      37879.0
# 18    TN      37398.0
# 19    TN      38501.0
# 20    TN      37604.0
# 21    TN      37172.0
# 22    TN      37371.0
# 23    TN      38024.0
# 24    TN      37205.0
# 25    TN      38556.0
# 26    TN      37404.0
# 27    TN      37404.0
# 28    TN      37403.0
# 29    TN      38372.0
# 30    TN      37772.0
# 31    TN      37208.0
# 32    TN      37917.0
# 33    TN      37916.0
# 34    TN      37236.0
# 35    TN      37076.0
# 36    TN      37203.0
# 37    TN      37923.0
# 38    TN      37087.0
# 39    TN      37075.0
# 40    TN      37211.0
# 41    TN      37167.0
# 0     TN      38401.0
# 1     TN      37148.0
# 2     TN      38401.0
# 18    TN  372031028.0
# 19    TN  380163307.0
# 20    TN  374211984.0
# 21    TN  381175701.0
# 26    TN      37604.0

# %%
# # drop duplicates
# all_providers = all_providers.drop_duplicates(keep=False)
# all_providers

# %%
all_providers.tail()
# Out:
#                           address   address2          city       full_name  \
# 10074  3601 the vanderbilt clinic        NaN     Nashville  Tiffany Street
# 10101                975 e 3rd st        NaN   Chattanooga    Jasmine Shah
# 10102                975 e 3rd st        NaN   Chattanooga    Jasmine Shah
# 10109           5301 virginia way  Suite 300     Brentwood    Farrukh Gill
# 10110       1124 new highway 52 e        NaN  Westmoreland    Amanda Perry
#
#         latitude  longitude state          zip
# 10074        NaN        NaN    TN  372320014.0
# 10101        NaN        NaN    TN  374032147.0
# 10102        NaN        NaN    TN  374032147.0
# 10109  36.032856  -86.80924    TN  370277541.0
# 10110        NaN        NaN    TN  371865060.0

# %%
# export unique addresses for geocoding later
# all_providers_addresses = all_providers[['address','city', 'state', 'zip']]

# drop duplicate addresses
all_providers.drop_duplicates(keep=False,inplace=True)

all_providers.tail()
# Out:
#                         address   address2          city        full_name  \
# 10049  710 carl perkins parkway        NaN   Tiptonville      Carol Guess
# 10050        2805 old fort pkwy    Suite d  Murfreesboro      Amy Bennett
# 10054          415 n lindell st        NaN        Martin  Phillip Elliott
# 10109         5301 virginia way  Suite 300     Brentwood     Farrukh Gill
# 10110     1124 new highway 52 e        NaN  Westmoreland     Amanda Perry
#
#         latitude  longitude state          zip
# 10049  36.369045  -89.46850    TN  380791305.0
# 10050  35.844967  -86.44899    TN  371285115.0
# 10054        NaN        NaN    TN      38237.0
# 10109  36.032856  -86.80924    TN  370277541.0
# 10110        NaN        NaN    TN  371865060.0

# %%
all_providers.head()
# Out:
#                          address address2        city  \
# 0            555 Hartsville Pike      NaN    Gallatin
# 1            3441 Dickerson Pike      NaN   Nashville
# 2                  421 S Main St      NaN  Crossville
# 3  907 E Lamar Alexander Parkway      NaN   Maryville
# 4          One Medical Park Blvd      NaN     Bristol
#
#                                   full_name   latitude  longitude state  \
# 0            Sumner Regional Medical Center        NaN        NaN    TN
# 1            Tristar Skyline Medical Center        NaN        NaN    TN
# 2                 Cumberland Medical Center        NaN        NaN    TN
# 3                  Blount Memorial Hospital  35.754974   -83.9591    TN
# 4  Wellmont Bristol Regional Medical Center        NaN        NaN    TN
#
#        zip
# 0  37066.0
# 1  37207.0
# 2  38555.0
# 3  37804.0
# 4  37620.0

# %%
# all_providers_addresses.info()

# # NOTE: zip colim needs to be an integer to work with online geocoder at: 
# # https://geocoding.geo.census.gov/geocoder/geographies/addressbatch?form

# # df['column name'] = df['column name'].astype(np.int64)
# all_providers_addresses['zip'] = all_providers_addresses['zip'].astype(np.int64)

# %%
all_providers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1366 entries, 0 to 10110
# Data columns (total 8 columns):
# address      1366 non-null object
# address2     448 non-null object
# city         1366 non-null object
# full_name    1366 non-null object
# latitude     973 non-null float64
# longitude    973 non-null float64
# state        1366 non-null object
# zip          1366 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 96.0+ KB

# %%
# export address dataframe for geocoding
# all_providers.to_csv('../data/clean/all_providers.csv')
all_providers.to_csv('../data/clean/all_providers_geocoded_addresses.csv')

# %% [markdown]
# ## NOTE: This notebook needs some cleaning up. The cells below are no longer being used. There are also a few above that have been commented out.

# %%
# NOTE This info may no longer be needed


########################### READ ME FOR LATER #################################
# NOTE: The addresses file will go through the geocoder and return the following format: "","xxx",""
#     This is a comma-delimited format with double quotes around each cell. I've been goint into BBEdit and
#     deleting the double quotes. Loads fine after that, but you'll still need to add column names, see below.
   
# Keep these columns 
#     - drop_me
#     - address
#     - city
#     - state
#     - zip
#     - No_Match
#     - match_type
#     - longitude
#     - latitude

# Drop these columns
#     - street2
#     - city2
#     - state2
#     - zip2
#     - unknown
#     - unknown2
#     - unknown3
#     - unknown4
#     - unknown5
#     - unknown6

# %%
# # set up import variables
# all_providers_geocodes_csv = '../data/clean/all_providers_geocodes.csv'
# columns = ['address', ' city', ' state', ' zip', 'longitude', 'latitude'] 


# # import files to dataframes
# all_providers_geocodes = pd.read_csv(all_providers_geocodes_csv, usecols=columns)

# # delete initial space in column names
# all_providers_geocodes.columns = all_providers_geocodes.columns.str.replace(' ', '').str.lower()

# all_providers_geocodes.info()

# %%
# # join geocoded addresses
# # pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
# #          left_index=False, right_index=False, sort=True,
# #          suffixes=('_x', '_y'), copy=True, indicator=False,
# #          validate=None)

# #DEBUGDEBUG This is not working correctly
# result = pd.merge(all_providers, all_providers_geocodes, how='right', on=['address'])

# result.tail(50)

# %%
# # fix column names
# new_names = ['address', 'address2', 'apc', 'apc_description', 'city_x', 'first_name',
#        'full_name', 'hcpcs_code', 'hcpcs_description', 'last_name',
#        'provider_type', 'state_x', 'zip_x', 'city', 'state', 'zip',
#        'longitude', 'latitude']


# result.columns = new_names

# result.columns

# %%
# # create all_providers_geocode_addresses
# all_providers_geocoded_addresses = result[['full_name', 'first_name', 'last_name', 'address', 'address2',
#                                           'city', 'state', 'zip', 'longitude', 'latitude', 'apc', 'apc_description',
#                                           'hcpcs_code', 'hcpcs_description', 'provider_type']]

# all_providers_geocoded_addresses.tail(50)

# %%
# # save new dataframes
# all_providers.to_csv('../data/clean/all_providers.csv')
# all_providers_geocoded_addresses.to_csv('../data/clean/all_providers_geocoded_addresses.csv')
